# %%
import pandas as pd
import datetime as dt

# %%
music_0603 = pd.read_csv('music_data.csv')
music_0603
# Out:
#     Unnamed: 0              Song ID                         Song Name  \
# 0            0  6808287098886424577  Then Leave (feat. Queendom Come)
# 1            1  6808287098886424577  Then Leave (feat. Queendom Come)
# 2            2  6813134956269947654    Stunnin' (feat. Harm Franklin)
# 3            3  6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4            4  6812545347835922434                         Hood Baby
# 5            5  6807966889273346822                        Dream Girl
# 6            6  6827517892439968517                             Do It
# 7            7  6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8            8  6754420279457565445                      Mr. Blue Sky
# 9            9  6746993352891189249          Monkeys Spinning Monkeys
# 10          10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                       Artist  \
# 0                   BeatKing
# 1                   BeatKing
# 2              Curtis Waters
# ...

# %%
date = dt.date(2021, 6, 3)

# %%
music_0603['Date'] = date

# %%
music_clean_0603 = music_0603.drop(labels=[0,3], axis=0)
music_clean_0603
# Out:
#     Unnamed: 0              Song ID                         Song Name  \
# 1            1  6808287098886424577  Then Leave (feat. Queendom Come)
# 2            2  6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4            4  6812545347835922434                         Hood Baby
# 5            5  6807966889273346822                        Dream Girl
# 6            6  6827517892439968517                             Do It
# 7            7  6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8            8  6754420279457565445                      Mr. Blue Sky
# 9            9  6746993352891189249          Monkeys Spinning Monkeys
# 10          10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                       Artist  \
# 1                   BeatKing
# 2              Curtis Waters
# 4                       Kbfr
# 5                    Ir Sais
# 6              Chloe x Halle
# 7   Jawsh 685 & Jason Derulo
# 8   Electric Light Orchestra
# ...

# %%
music_0609 = pd.read_csv('music_data0609.csv')
music_0609
# Out:
#    Unnamed: 0              Song ID                         Song Name  \
# 0           0  6808287098886424577  Then Leave (feat. Queendom Come)
# 1           1  6812545347835922434                         Hood Baby
# 2           2  6807966889273346822                        Dream Girl
# 3           3  6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4           4  6827517892439968517                             Do It
# 5           5  6834110584288447237  Savage Love (Laxed - Siren Beat)
# 6           6  6754420279457565445                      Mr. Blue Sky
# 7           7  6746993352891189249          Monkeys Spinning Monkeys
# 8           8  6691366574592396038            Woah (feat. D3Mstreet)
#
#                      Artist  \
# 0                  BeatKing
# 1                      Kbfr
# 2                   Ir Sais
# 3             Curtis Waters
# 4             Chloe x Halle
# 5  Jawsh 685 & Jason Derulo
# 6  Electric Light Orchestra
# 7             Kevin MacLeod
# ...

# %%
date1 = dt.date(2021, 6, 9)
music_0609['Date'] = date1
music_0609
# Out:
#    Unnamed: 0              Song ID                         Song Name  \
# 0           0  6808287098886424577  Then Leave (feat. Queendom Come)
# 1           1  6812545347835922434                         Hood Baby
# 2           2  6807966889273346822                        Dream Girl
# 3           3  6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4           4  6827517892439968517                             Do It
# 5           5  6834110584288447237  Savage Love (Laxed - Siren Beat)
# 6           6  6754420279457565445                      Mr. Blue Sky
# 7           7  6746993352891189249          Monkeys Spinning Monkeys
# 8           8  6691366574592396038            Woah (feat. D3Mstreet)
#
#                      Artist  \
# 0                  BeatKing
# 1                      Kbfr
# 2                   Ir Sais
# 3             Curtis Waters
# 4             Chloe x Halle
# 5  Jawsh 685 & Jason Derulo
# 6  Electric Light Orchestra
# 7             Kevin MacLeod
# ...

# %%
tiktok_growth = pd.DataFrame.append(music_clean_0603, music_0609).drop(columns='Unnamed: 0')
tiktok_growth
# Out:
#                 Song ID                         Song Name  \
# 1   6808287098886424577  Then Leave (feat. Queendom Come)
# 2   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6812545347835922434                         Hood Baby
# 5   6807966889273346822                        Dream Girl
# 6   6827517892439968517                             Do It
# 7   6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8   6754420279457565445                      Mr. Blue Sky
# 9   6746993352891189249          Monkeys Spinning Monkeys
# 10  6691366574592396038            Woah (feat. D3Mstreet)
# 0   6808287098886424577  Then Leave (feat. Queendom Come)
# 1   6812545347835922434                         Hood Baby
# 2   6807966889273346822                        Dream Girl
# 3   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6827517892439968517                             Do It
# 5   6834110584288447237  Savage Love (Laxed - Siren Beat)
# ...

# %%
tiktok_growth.to_csv('tiktok_growth.csv')
