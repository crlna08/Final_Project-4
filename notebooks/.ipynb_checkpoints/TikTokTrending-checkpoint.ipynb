# %%
import requests

url = "https://tiktok-trending-data.p.rapidapi.com/t"

headers = {
    'x-rapidapi-key': "86012d1ee8msh9e6fcf09224f8e6p185a74jsn60c6b9ca1ca2",
    'x-rapidapi-host': "tiktok-trending-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"statusCode":0,"body":[{"pageState":{},"exploreList":[{"cardItem":{"id":"5831967","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/0a0242e5f906bf9301f859c568b5ecc4~c5_100x100.jpeg?x-expires=1623178800&x-signature=fl4pSXtaxpGwlaIiFaV1le4YwtE%3D","title":"charli d’amelio","subTitle":"@charlidamelio","description":"","link":"/@charlidamelio","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":117200000,"likes":"9400000000","userId":"5831967","secUid":"MS4wLjABAAAA-VASjiXTh7wDDyXvjk10VFhMWUAoxr8bgfO1kAL1-9s","relation":-1,"roomId":""}}},{"cardItem":{"id":"6748458643983238149","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/01d747eeb63f0cef2cc05a0099ab74e3~c5_100x100.jpeg?x-expires=1623178800&x-signature=SBK5%2FlTTkHQu0zsHsyzLO4PlFGc%3D","title":"Bella Poarch","subTitle":"@bellapoarch","description":"BUILD A BITCH MUSIC VIDEO OUT NOW😈","link":"/@bellapoarch","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":72000000,"likes":"1600000000","userId":"6748458643983238149","secUid":"MS4wLjABAAAAIQGNoHByQvokcLbWCGnIfas0OV2nctsZnRFbN7eB04xt-9usrHe3UvXJRZLxBWlJ","relation":-1,"roomId":""}}},{"cardItem":{"id":"6703550784929793030","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/69e3328223da5577e78ce7f33729c2dd~c5_100x100.jpeg?x-expires=1623178800&x-signature=5fOiFMuGyffBnMURFig4NMlafvg%3D","title":"addison rae","subTitle":"@addisonre","description":"OBSESSED out on all platforms.","link":"/@addisonre","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":80900000,"likes":"5200000000","userId":"6703550784929793030","secUid":"MS4wLjABAAAAVjQK614JSGmZVT3EVAiSDfznaBJOVfWPrtqDsQ9YxU368ewQrTyyEOb3OtJb4xCI","relation":-1,"roomId":""}}},{"cardItem":{"id":"6780564068844880902","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/626784dddbff91e8db9e179949622a53~c5_100x100.jpeg?x-expires=1623178800&x-signature=HLKsOJtofgGzLyE5OeWyUZsot9Q%3D","title":"Mia Khalifa","subTitle":"@miakhalifa","description":"Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co","link":"/@miakhalifa","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":23400000,"likes":"295700000","userId":"6780564068844880902","secUid":"MS4wLjABAAAAqRy-nnmorDVMJ1JddqSqduRvlpsNEiZN8ADzdePW-bRdBYVRjcgE4g8NMcyd9Sbp","relation":-1,"roomId":""}}},{"cardItem":{"id":"6739078402710553605","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1658853392415749~c5_100x100.jpeg?x-expires=1623178800&x-signature=zEs0DvjU3%2FKyqvCDoX%2F90aHu7qI%3D","title":"Dr. Daniel Aronov","subTitle":"@dr.danielaronov","description":"See ALL my surgeries on my Instagram! INQUIRIES? 👉 DM me on Instagram","link":"/@dr.danielaronov","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":12500000,"likes":"220800000","userId":"6739078402710553605","secUid":"MS4wLjABAAAADfrPcyWFROfYl4vfjYJ9_g4hCUwaNqG-FCm83dbOgohdee8YSlFv0H8rs6SOkKUZ","relation":-1,"roomId":""}}},{"cardItem":{"id":"6654362767867265030","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/9291601308707957042cdedd2b77a85e~c5_100x100.jpeg?x-expires=1623178800&x-signature=f8d9UImL9sIr5nHbGG5R6rYNgh4%3D","title":"Kylie Jenner ","subTitle":"@kyliejenner","description":"The official account of Kylie Jenner","link":"/@kyliejenner","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":32300000,"likes":"372600000","userId":"6654362767867265030","secUid":"MS4wLjABAAAArK0Wz24jqHzcTuvH6y7H0KZJEbfgbCp03noTihWxrNYt26w2Fl6FAwCF-RRbNnOL","relation":-1,"roomId":""}}},{"cardItem":{"id":"6663294979903422470","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1627299377282054~c5_100x100.jpeg?x-expires=1623178800&x-signature=E8qqDmVz8GBNLxsoeEKg96i2iw8%3D","title":"ESPN","subTitle":"@espn","description":"You won’t regret following! 🔥","link":"/@espn","round":true,"playToken":"","keyToken":" ...

# %%
import json
import pandas as pd
trending_json = json.loads(response.text)

# %%
parsed_data = {
    "id": [],
    "type": [],
    "cover": [],
    "title": [],
    "subTitle": [],
    "description": [],
    "link": [],
    "round": [],
    "playToken": [],
    "keyToken": [],
    "extraInfo": []
}

# %%
for type_result in trending_json["body"]:
    for item in type_result["exploreList"]:
        for k in item["cardItem"].keys():
                val = item["cardItem"].get(k)
                #print(val)
                parsed_data.get(k).append(val)

# %%
parsed_df = pd.DataFrame(parsed_data)
parsed_df
# Out:
#                      id  type  \
# 0               5831967     2
# 1   6748458643983238149     2
# 2   6703550784929793030     2
# 3   6780564068844880902     2
# 4   6739078402710553605     2
# 5   6654362767867265030     2
# 6   6663294979903422470     2
# 7   6813630187164533765     2
# 8   6669716864531054598     2
# 9   6905042173626008581     2
# 10  6879693940111901701     2
# 11    84635664075374592     2
# 12  6957597538883142661     2
# 13  6544081646253342726     2
# 14  6746417382892176389     2
# 15              7239462     2
# 16  6775033566016963589     2
# 17  6718992235998741510     2
# 18              1180651     2
# 19  6625714545389142022     2
# 20  6732675975610074118     2
# 21  6904838098921440262     2
# 22              9881080     2
# 23    91752822198640640     2
# 24  6646764999833403398     2
# 25  6699542567460389894     2
# 26             17309235     2
# 27               107955     2
# 28  6767527973299536901     2
# 29  6716859375102870533     2
# 30                47560     3
# 31               310374     3
# 32     1599163184670722     3
# 33             22374995     3
# 34               569056     3
# 35                80713     3
# 36               400318     3
# 37     1647119754150918     3
# 38     1662027712917510     3
# 39     1637138684632070     3
# 40  6808287098886424577     1
# 41  6812545347835922434     1
# 42  6807966889273346822     1
# 43  6813134956269947654     1
# 44  6827517892439968517     1
# 45  6834110584288447237     1
# 46  6754420279457565445     1
# 47  6746993352891189249     1
# 48  6691366574592396038     1
#
#                                                 cover  \
# 0   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 1   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 2   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 3   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 5   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 7   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 9   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 10  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 12  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 14  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 15  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 17  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 18  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 23  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 24  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 29  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 30  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 31  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 32  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 33  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 34  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 35  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 36  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 37  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 38  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 39  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 40  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 41  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 42  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 43  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 44  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 45  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 46  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 47  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 48  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
#
#                                title             subTitle  \
# 0                    charli d’amelio       @charlidamelio
# 1                       Bella Poarch         @bellapoarch
# 2                        addison rae           @addisonre
# 3                        Mia Khalifa          @miakhalifa
# 4                  Dr. Daniel Aronov     @dr.danielaronov
# 5                      Kylie Jenner          @kyliejenner
# 6                               ESPN                @espn
# 7                          siennamae           @siennamae
# 8                    Brody Wellmaker      @brodywellmaker
# 9                        Monkey keer          @monkeykeer
# 10                     BILLIE EILISH        @billieeilish
# 11                             lizzo               @lizzo
# 12                    LIGHTS ARE OFF      @lights.are.off
# 13                                Ri               @riwww
# 14                         KEEMOKAZI           @keemokazi
# 15                      Malu Trevejo         @malutrevejo
# 16                         noah beck            @noahbeck
# 17                           Scott 🔥       @scottsreality
# 18                       bretmanrock         @bretmanrock
# 19                          Overtime            @overtime
# 20                       Brooke Monk         @brookemonk_
# 21                    northeasterner      @northeasterner
# 22                       jack wright         @jack.wright
# 23                          Savage 😈            @itsavage
# 24                   Barstool Sports      @barstoolsports
# 25                        Jay Brewer  @jayprehistoricpets
# 26                  Gary Vaynerchuk              @garyvee
# 27                            TikTok              @tiktok
# 28                      AbbieHerbert       @abbieherbert_
# 29                  Wren & Jacquelyn        @wren.eleanor
# 30                     #summerschool          37.2M views
# 31                        #goodpoint          35.5M views
# 32                       #foodtiktok          18.3B views
# 33                 #intothethickofit         520.8M views
# 34                      #ecofriendly           1.3B views
# 35                       #blackmusic           309M views
# 36                        #buffering         690.4M views
# 37                #tiktokmademebuyit           2.9B views
# 38                     #prideanthems          80.2M views
# 39                     #foryourpride         757.9M views
# 40  Then Leave (feat. Queendom Come)          1.1M videos
# 41                         Hood Baby          2.8M videos
# 42                        Dream Girl         13.4M videos
# 43    Stunnin' (feat. Harm Franklin)          1.1M videos
# 44                             Do It        466.9K videos
# 45  Savage Love (Laxed - Siren Beat)          781K videos
# 46                      Mr. Blue Sky        545.3K videos
# 47          Monkeys Spinning Monkeys         10.1M videos
# 48            Woah (feat. D3Mstreet)         12.4M videos
#
#                                           description  \
# 0
# 1                  BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 2                      OBSESSED out on all platforms.
# 3        Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co
# 4   See ALL my surgeries on my Instagram! INQUIRIE...
# 5                The official account of Kylie Jenner
# 6                       You won’t regret following! 🔥
# 7                   I’ll be famous one day\nceo of 🐿💨
# 8   Trying to sneak my way into Hollywood 🤫 \nbrod...
# 9                Thanks to all friends who follow me.
# 10                                                 19
# 11                                    100% that bitch
# 12  LIGHTS ARE OFF\nI bring nightmares to life eve...
# 13  I’m Renata. 18\nthx 7m \ninsta: @ri.www\nRi.co...
# 14  Following back on IG for the next 24 hours ↖️🔥...
# 15                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋
# 16  ur luv’d<3\ndo what makes you happy\nbusiness:...
# 17  Donating to new IG followers!💰 \n📧 Scott@grail...
# 18                                             legend
# 19  Best page in the galaxy 💫\nThanks for being my...
# 20  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...
# 21                 Follow me to watch more food video
# 22                spread positivity😁\nfollow the gram
# 23  CEO Of It Works 😃👍\n-\nBuisness - HendrickGold...
# 24          🗣 Viva La Stool\n\nGoing viral is a sport
# 25  Sub to my YouTube for even more animal fun see...
# 26  🔑 Entrepreneur\n🔮 Investor in Uber, Snap, Venm...
# 27                                It Starts On TikTok
# 28  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...
# 29  Wren PO Box 461243 Papillion, NE 68046 📬\nteam...
# 30  Whether you're hitting the books or picking up...
# 31  That's a really #GoodPoint Diane, thank you so...
# 32  Your one-stop shop for perfect recipes, delici...
# 33  We're tramping through the bush. On and on we ...
# 34  Whether you love to upcycle or always make sur...
# 35  June is Black Music Month, and TikTok is celeb...
# 36  Use our Creative Effect and show us what happe...
# 37  Whether you're still hunting for feta cheese o...
# 38  Whether it's an iconic bop that's been an esse...
# 39  Pride Month is here, and TikTok is celebrating...
# 40                                           BeatKing
# 41                                               Kbfr
# 42                                            Ir Sais
# 43                                      Curtis Waters
# 44                                      Chloe x Halle
# 45                           Jawsh 685 & Jason Derulo
# 46                           Electric Light Orchestra
# 47                                      Kevin MacLeod
# 48                                         KRYPTO9095
#
#                                                  link  round playToken  \
# 0                                     /@charlidamelio   True
# 1                                       /@bellapoarch   True
# 2                                         /@addisonre   True
# 3                                        /@miakhalifa   True
# 4                                   /@dr.danielaronov   True
# 5                                       /@kyliejenner   True
# 6                                              /@espn   True
# 7                                         /@siennamae   True
# 8                                    /@brodywellmaker   True
# 9                                        /@monkeykeer   True
# 10                                     /@billieeilish   True
# 11                                            /@lizzo   True
# 12                                   /@lights.are.off   True
# 13                                            /@riwww   True
# 14                                        /@keemokazi   True
# 15                                      /@malutrevejo   True
# 16                                         /@noahbeck   True
# 17                                    /@scottsreality   True
# 18                                      /@bretmanrock   True
# 19                                         /@overtime   True
# 20                                      /@brookemonk_   True
# 21                                   /@northeasterner   True
# 22                                      /@jack.wright   True
# 23                                         /@itsavage   True
# 24                                   /@barstoolsports   True
# 25                               /@jayprehistoricpets   True
# 26                                          /@garyvee   True
# 27                                           /@tiktok   True
# 28                                    /@abbieherbert_   True
# 29                                     /@wren.eleanor   True
# 30                                  /tag/summerschool  False
# 31                                     /tag/goodpoint  False
# 32                                    /tag/foodtiktok  False
# 33                              /tag/intothethickofit  False
# 34                                   /tag/ecofriendly  False
# 35                                    /tag/blackmusic  False
# 36                                     /tag/buffering  False
# 37                             /tag/tiktokmademebuyit  False
# 38                                  /tag/prideanthems  False
# 39                                  /tag/foryourpride  False
# 40  /music/Then-Leave-feat-Queendom-Come-680828709...  False
# 41               /music/Hood-Baby-6812545347835922434  False
# 42              /music/Dream-Girl-6807966889273346822  False
# 43  /music/Stunnin-feat-Harm-Franklin-681313495626...  False
# 44                   /music/Do-It-6827517892439968517  False
# 45  /music/Savage-Love-Laxed-Siren-Beat-6834110584...  False
# 46             /music/Mr-Blue-Sky-6754420279457565445  False
# 47  /music/Monkeys-Spinning-Monkeys-67469933528911...  False
# 48     /music/Woah-feat-D3Mstreet-6691366574592396038  False
#
#    keyToken                                          extraInfo
# 0            {'verified': True, 'fans': 117200000, 'likes':...
# 1            {'verified': True, 'fans': 72000000, 'likes': ...
# 2            {'verified': True, 'fans': 80900000, 'likes': ...
# 3            {'verified': True, 'fans': 23400000, 'likes': ...
# 4            {'verified': True, 'fans': 12500000, 'likes': ...
# 5            {'verified': True, 'fans': 32300000, 'likes': ...
# 6            {'verified': True, 'fans': 16600000, 'likes': ...
# 7            {'verified': True, 'fans': 14400000, 'likes': ...
# 8            {'verified': True, 'fans': 12100000, 'likes': ...
# 9            {'verified': False, 'fans': 6600000, 'likes': ...
# 10           {'verified': True, 'fans': 30400000, 'likes': ...
# 11           {'verified': True, 'fans': 16100000, 'likes': ...
# 12           {'verified': False, 'fans': 6000000, 'likes': ...
# 13           {'verified': False, 'fans': 7200000, 'likes': ...
# 14           {'verified': True, 'fans': 18400000, 'likes': ...
# 15           {'verified': True, 'fans': 17600000, 'likes': ...
# 16           {'verified': True, 'fans': 27400000, 'likes': ...
# 17           {'verified': True, 'fans': 24300000, 'likes': ...
# 18           {'verified': True, 'fans': 11400000, 'likes': ...
# 19           {'verified': True, 'fans': 16800000, 'likes': ...
# 20           {'verified': True, 'fans': 15500000, 'likes': ...
# 21           {'verified': False, 'fans': 5500000, 'likes': ...
# 22           {'verified': True, 'fans': 8500000, 'likes': '...
# 23           {'verified': True, 'fans': 12600000, 'likes': ...
# 24           {'verified': True, 'fans': 13600000, 'likes': ...
# 25           {'verified': True, 'fans': 13500000, 'likes': ...
# 26           {'verified': True, 'fans': 6600000, 'likes': '...
# 27           {'verified': True, 'fans': 54400000, 'likes': ...
# 28           {'verified': True, 'fans': 8800000, 'likes': '...
# 29           {'verified': False, 'fans': 11000000, 'likes':...
# 30           {'views': '37200000', 'challengeId': '47560', ...
# 31           {'views': '35500000', 'challengeId': '310374',...
# 32           {'views': '18300000000', 'challengeId': '15991...
# 33           {'views': '520800000', 'challengeId': '2237499...
# 34           {'views': '1300000000', 'challengeId': '569056...
# 35           {'views': '309000000', 'challengeId': '80713',...
# 36           {'views': '690400000', 'challengeId': '400318'...
# 37           {'views': '2900000000', 'challengeId': '164711...
# 38           {'views': '80200000', 'challengeId': '16620277...
# 39           {'views': '757900000', 'challengeId': '1637138...
# 40           {'musicId': '6808287098886424577', 'playUrl': ...
# 41           {'musicId': '6812545347835922434', 'playUrl': ...
# 42           {'musicId': '6807966889273346822', 'playUrl': ...
# 43           {'musicId': '6813134956269947654', 'playUrl': ...
# 44           {'musicId': '6827517892439968517', 'playUrl': ...
# 45           {'musicId': '6834110584288447237', 'playUrl': ...
# 46           {'musicId': '6754420279457565445', 'playUrl': ...
# 47           {'musicId': '6746993352891189249', 'playUrl': ...
# 48           {'musicId': '6691366574592396038', 'playUrl': ...

# %%
extrainfo_keys = []

for info in parsed_df['extraInfo']:
    extrainfo_keys += (list(info.keys()))
extrainfo_keys = list(set(extrainfo_keys))
extrainfo_keys
# Out:
# ['playUrl',
#  'secUid',
#  'views',
#  'relation',
#  'userId',
#  'likes',
#  'challengeId',
#  'fans',
#  'verified',
#  'posts',
#  'musicId',
#  'challengeName',
#  'roomId']

# %%
for infokey in extrainfo_keys:
    parsed_df[infokey] = parsed_df['extraInfo'].apply(lambda x: x.get(infokey))
parsed_df.head()
# Out:
#                     id  type  \
# 0              5831967     2
# 1  6748458643983238149     2
# 2  6703550784929793030     2
# 3  6780564068844880902     2
# 4  6739078402710553605     2
#
#                                                cover              title  \
# 0  https://p16-sign-va.tiktokcdn.com/musically-ma...    charli d’amelio
# 1  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Bella Poarch
# 2  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        addison rae
# 3  https://p16-sign-va.tiktokcdn.com/musically-ma...        Mia Khalifa
# 4  https://p16-sign-va.tiktokcdn.com/musically-ma...  Dr. Daniel Aronov
#
#            subTitle                                        description  \
# 0    @charlidamelio
# 1      @bellapoarch                 BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 2        @addisonre                     OBSESSED out on all platforms.
# 3       @miakhalifa       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co
# 4  @dr.danielaronov  See ALL my surgeries on my Instagram! INQUIRIE...
#
#                 link  round playToken keyToken  ... relation  \
# 0    /@charlidamelio   True                     ...     -1.0
# 1      /@bellapoarch   True                     ...     -1.0
# 2        /@addisonre   True                     ...     -1.0
# 3       /@miakhalifa   True                     ...     -1.0
# 4  /@dr.danielaronov   True                     ...     -1.0
#
#                 userId       likes challengeId         fans verified posts  \
# 0              5831967  9400000000        None  117200000.0     True   NaN
# 1  6748458643983238149  1600000000        None   72000000.0     True   NaN
# 2  6703550784929793030  5200000000        None   80900000.0     True   NaN
# 3  6780564068844880902   295700000        None   23400000.0     True   NaN
# 4  6739078402710553605   220800000        None   12500000.0     True   NaN
#
#   musicId  challengeName roomId
# 0    None           None
# 1    None           None
# 2    None           None
# 3    None           None
# 4    None           None
#
# [5 rows x 24 columns]

# %%
music_df = parsed_df[parsed_df['type'] == 1]
music_df
# Out:
#                      id  type  \
# 40  6808287098886424577     1
# 41  6812545347835922434     1
# 42  6807966889273346822     1
# 43  6813134956269947654     1
# 44  6827517892439968517     1
# 45  6834110584288447237     1
# 46  6754420279457565445     1
# 47  6746993352891189249     1
# 48  6691366574592396038     1
#
#                                                 cover  \
# 40  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 41  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 42  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 43  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 44  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 45  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 46  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 47  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 48  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
#
#                                title       subTitle               description  \
# 40  Then Leave (feat. Queendom Come)    1.1M videos                  BeatKing
# 41                         Hood Baby    2.8M videos                      Kbfr
# 42                        Dream Girl   13.4M videos                   Ir Sais
# 43    Stunnin' (feat. Harm Franklin)    1.1M videos             Curtis Waters
# 44                             Do It  466.9K videos             Chloe x Halle
# 45  Savage Love (Laxed - Siren Beat)    781K videos  Jawsh 685 & Jason Derulo
# 46                      Mr. Blue Sky  545.3K videos  Electric Light Orchestra
# 47          Monkeys Spinning Monkeys   10.1M videos             Kevin MacLeod
# 48            Woah (feat. D3Mstreet)   12.4M videos                KRYPTO9095
#
#                                                  link  round playToken  \
# 40  /music/Then-Leave-feat-Queendom-Come-680828709...  False
# 41               /music/Hood-Baby-6812545347835922434  False
# 42              /music/Dream-Girl-6807966889273346822  False
# 43  /music/Stunnin-feat-Harm-Franklin-681313495626...  False
# 44                   /music/Do-It-6827517892439968517  False
# 45  /music/Savage-Love-Laxed-Siren-Beat-6834110584...  False
# 46             /music/Mr-Blue-Sky-6754420279457565445  False
# 47  /music/Monkeys-Spinning-Monkeys-67469933528911...  False
# 48     /music/Woah-feat-D3Mstreet-6691366574592396038  False
#
#    keyToken  ... relation userId likes challengeId  fans verified       posts  \
# 40           ...      NaN   None  None        None   NaN     None   1100000.0
# 41           ...      NaN   None  None        None   NaN     None   2800000.0
# 42           ...      NaN   None  None        None   NaN     None  13400000.0
# 43           ...      NaN   None  None        None   NaN     None   1100000.0
# 44           ...      NaN   None  None        None   NaN     None    466900.0
# 45           ...      NaN   None  None        None   NaN     None    781000.0
# 46           ...      NaN   None  None        None   NaN     None    545300.0
# 47           ...      NaN   None  None        None   NaN     None  10100000.0
# 48           ...      NaN   None  None        None   NaN     None  12400000.0
#
#                 musicId  challengeName roomId
# 40  6808287098886424577           None   None
# 41  6812545347835922434           None   None
# 42  6807966889273346822           None   None
# 43  6813134956269947654           None   None
# 44  6827517892439968517           None   None
# 45  6834110584288447237           None   None
# 46  6754420279457565445           None   None
# 47  6746993352891189249           None   None
# 48  6691366574592396038           None   None
#
# [9 rows x 24 columns]

# %%
def parse_number(num: str) -> int:
    videos = num.split()[0]
    number = videos[:-1]
    units = videos[-1]
    units_mapper = {
        "K": 1,
        "M": 1000,
        "B": 1000000
    }
    return (float(number)) * float(units_mapper.get(units))

# %%
df = pd.DataFrame(music_df['subTitle'])
df
# Out:
#          subTitle
# 40    1.1M videos
# 41    2.8M videos
# 42   13.4M videos
# 43    1.1M videos
# 44  466.9K videos
# 45    781K videos
# 46  545.3K videos
# 47   10.1M videos
# 48   12.4M videos

# %%
df['videos_count (in thousands)'] = df['subTitle'].apply(parse_number)
df
# Out:
#          subTitle  videos_count (in thousands)
# 40    1.1M videos                       1100.0
# 41    2.8M videos                       2800.0
# 42   13.4M videos                      13400.0
# 43    1.1M videos                       1100.0
# 44  466.9K videos                        466.9
# 45    781K videos                        781.0
# 46  545.3K videos                        545.3
# 47   10.1M videos                      10100.0
# 48   12.4M videos                      12400.0

# %%
music_merged = pd.merge(music_df, df).drop(columns=
                                           ['subTitle',
                                            'cover', 
                                            'round', 
                                            'keyToken', 
                                            'playToken', 
                                            'extraInfo', 
                                            'type', 
                                            'extraInfo',
                                            'roomId',
                                            'fans',
                                            'verified',
                                            'relation',
                                            'challengeId',
                                            'musicId',
                                            'posts',
                                            'likes',
                                            'secUid',
                                            'userId',
                                            'challengeName',
                                            'views',
                                            'playUrl']).drop(labels=[0,3], axis=0)
music_merged
# Out:
#                      id                             title  \
# 1   6808287098886424577  Then Leave (feat. Queendom Come)
# 2   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6812545347835922434                         Hood Baby
# 5   6807966889273346822                        Dream Girl
# 6   6827517892439968517                             Do It
# 7   6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8   6754420279457565445                      Mr. Blue Sky
# 9   6746993352891189249          Monkeys Spinning Monkeys
# 10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                  description  \
# 1                   BeatKing
# 2              Curtis Waters
# 4                       Kbfr
# 5                    Ir Sais
# 6              Chloe x Halle
# 7   Jawsh 685 & Jason Derulo
# 8   Electric Light Orchestra
# 9              Kevin MacLeod
# 10                KRYPTO9095
#
#                                                  link  \
# 1   /music/Then-Leave-feat-Queendom-Come-680828709...
# 2   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 4                /music/Hood-Baby-6812545347835922434
# 5               /music/Dream-Girl-6807966889273346822
# 6                    /music/Do-It-6827517892439968517
# 7   /music/Savage-Love-Laxed-Siren-Beat-6834110584...
# 8              /music/Mr-Blue-Sky-6754420279457565445
# 9   /music/Monkeys-Spinning-Monkeys-67469933528911...
# 10     /music/Woah-feat-D3Mstreet-6691366574592396038
#
#     videos_count (in thousands)
# 1                        1100.0
# 2                        1100.0
# 4                        2800.0
# 5                       13400.0
# 6                         466.9
# 7                         781.0
# 8                         545.3
# 9                       10100.0
# 10                      12400.0

# %%
music_clean = music_merged.rename(columns={
    'id': 'Song ID',
    'title': 'Song Name',
    'description': 'Artist',
    'link': 'Link to Trend Page',
    'videos_count (in thousands)': 'Number of Videos with Song (in Thousands)'
})
music_clean
# Out:
#                 Song ID                         Song Name  \
# 1   6808287098886424577  Then Leave (feat. Queendom Come)
# 2   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6812545347835922434                         Hood Baby
# 5   6807966889273346822                        Dream Girl
# 6   6827517892439968517                             Do It
# 7   6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8   6754420279457565445                      Mr. Blue Sky
# 9   6746993352891189249          Monkeys Spinning Monkeys
# 10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                       Artist  \
# 1                   BeatKing
# 2              Curtis Waters
# 4                       Kbfr
# 5                    Ir Sais
# 6              Chloe x Halle
# 7   Jawsh 685 & Jason Derulo
# 8   Electric Light Orchestra
# 9              Kevin MacLeod
# 10                KRYPTO9095
#
#                                    Link to Trend Page  \
# 1   /music/Then-Leave-feat-Queendom-Come-680828709...
# 2   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 4                /music/Hood-Baby-6812545347835922434
# 5               /music/Dream-Girl-6807966889273346822
# 6                    /music/Do-It-6827517892439968517
# 7   /music/Savage-Love-Laxed-Siren-Beat-6834110584...
# 8              /music/Mr-Blue-Sky-6754420279457565445
# 9   /music/Monkeys-Spinning-Monkeys-67469933528911...
# 10     /music/Woah-feat-D3Mstreet-6691366574592396038
#
#     Number of Videos with Song (in Thousands)
# 1                                      1100.0
# 2                                      1100.0
# 4                                      2800.0
# 5                                     13400.0
# 6                                       466.9
# 7                                       781.0
# 8                                       545.3
# 9                                     10100.0
# 10                                    12400.0

# %%
music_clean.to_csv('music_data0603.csv')

# %%
users_df = parsed_df[parsed_df['type'] == 2]
users_df
# Out:
#                      id  type  \
# 0               5831967     2
# 1   6748458643983238149     2
# 2   6703550784929793030     2
# 3   6780564068844880902     2
# 4   6739078402710553605     2
# 5   6654362767867265030     2
# 6   6663294979903422470     2
# 7   6813630187164533765     2
# 8   6669716864531054598     2
# 9   6905042173626008581     2
# 10  6879693940111901701     2
# 11    84635664075374592     2
# 12  6957597538883142661     2
# 13  6544081646253342726     2
# 14  6746417382892176389     2
# 15              7239462     2
# 16  6775033566016963589     2
# 17  6718992235998741510     2
# 18              1180651     2
# 19  6625714545389142022     2
# 20  6732675975610074118     2
# 21  6904838098921440262     2
# 22              9881080     2
# 23    91752822198640640     2
# 24  6646764999833403398     2
# 25  6699542567460389894     2
# 26             17309235     2
# 27               107955     2
# 28  6767527973299536901     2
# 29  6716859375102870533     2
#
#                                                 cover              title  \
# 0   https://p16-sign-va.tiktokcdn.com/musically-ma...    charli d’amelio
# 1   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Bella Poarch
# 2   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        addison rae
# 3   https://p16-sign-va.tiktokcdn.com/musically-ma...        Mia Khalifa
# 4   https://p16-sign-va.tiktokcdn.com/musically-ma...  Dr. Daniel Aronov
# 5   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...      Kylie Jenner
# 6   https://p16-sign-va.tiktokcdn.com/musically-ma...               ESPN
# 7   https://p16-sign-va.tiktokcdn.com/musically-ma...          siennamae
# 8   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...    Brody Wellmaker
# 9   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        Monkey keer
# 10  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...      BILLIE EILISH
# 11  https://p16-sign-va.tiktokcdn.com/musically-ma...              lizzo
# 12  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...     LIGHTS ARE OFF
# 13  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...                 Ri
# 14  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...          KEEMOKAZI
# 15  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Malu Trevejo
# 16  https://p16-sign-va.tiktokcdn.com/musically-ma...          noah beck
# 17  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...            Scott 🔥
# 18  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        bretmanrock
# 19  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...           Overtime
# 20  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        Brooke Monk
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...     northeasterner
# 22  https://p16-sign-va.tiktokcdn.com/musically-ma...        jack wright
# 23  https://p16-sign-va.tiktokcdn.com/musically-ma...           Savage 😈
# 24  https://p16-sign-va.tiktokcdn.com/musically-ma...    Barstool Sports
# 25  https://p16-sign-va.tiktokcdn.com/musically-ma...         Jay Brewer
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...   Gary Vaynerchuk
# 27  https://p16-sign-va.tiktokcdn.com/musically-ma...             TikTok
# 28  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       AbbieHerbert
# 29  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...   Wren & Jacquelyn
#
#                subTitle                                        description  \
# 0        @charlidamelio
# 1          @bellapoarch                 BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 2            @addisonre                     OBSESSED out on all platforms.
# 3           @miakhalifa       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co
# 4      @dr.danielaronov  See ALL my surgeries on my Instagram! INQUIRIE...
# 5          @kyliejenner               The official account of Kylie Jenner
# 6                 @espn                      You won’t regret following! 🔥
# 7            @siennamae                  I’ll be famous one day\nceo of 🐿💨
# 8       @brodywellmaker  Trying to sneak my way into Hollywood 🤫 \nbrod...
# 9           @monkeykeer               Thanks to all friends who follow me.
# 10        @billieeilish                                                 19
# 11               @lizzo                                    100% that bitch
# 12      @lights.are.off  LIGHTS ARE OFF\nI bring nightmares to life eve...
# 13               @riwww  I’m Renata. 18\nthx 7m \ninsta: @ri.www\nRi.co...
# 14           @keemokazi  Following back on IG for the next 24 hours ↖️🔥...
# 15         @malutrevejo                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋
# 16            @noahbeck  ur luv’d<3\ndo what makes you happy\nbusiness:...
# 17       @scottsreality  Donating to new IG followers!💰 \n📧 Scott@grail...
# 18         @bretmanrock                                             legend
# 19            @overtime  Best page in the galaxy 💫\nThanks for being my...
# 20         @brookemonk_  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...
# 21      @northeasterner                 Follow me to watch more food video
# 22         @jack.wright                spread positivity😁\nfollow the gram
# 23            @itsavage  CEO Of It Works 😃👍\n-\nBuisness - HendrickGold...
# 24      @barstoolsports          🗣 Viva La Stool\n\nGoing viral is a sport
# 25  @jayprehistoricpets  Sub to my YouTube for even more animal fun see...
# 26             @garyvee  🔑 Entrepreneur\n🔮 Investor in Uber, Snap, Venm...
# 27              @tiktok                                It Starts On TikTok
# 28       @abbieherbert_  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...
# 29        @wren.eleanor  Wren PO Box 461243 Papillion, NE 68046 📬\nteam...
#
#                     link  round playToken keyToken  ... relation  \
# 0        /@charlidamelio   True                     ...     -1.0
# 1          /@bellapoarch   True                     ...     -1.0
# 2            /@addisonre   True                     ...     -1.0
# 3           /@miakhalifa   True                     ...     -1.0
# 4      /@dr.danielaronov   True                     ...     -1.0
# 5          /@kyliejenner   True                     ...     -1.0
# 6                 /@espn   True                     ...     -1.0
# 7            /@siennamae   True                     ...     -1.0
# 8       /@brodywellmaker   True                     ...     -1.0
# 9           /@monkeykeer   True                     ...     -1.0
# 10        /@billieeilish   True                     ...     -1.0
# 11               /@lizzo   True                     ...     -1.0
# 12      /@lights.are.off   True                     ...     -1.0
# 13               /@riwww   True                     ...     -1.0
# 14           /@keemokazi   True                     ...     -1.0
# 15         /@malutrevejo   True                     ...     -1.0
# 16            /@noahbeck   True                     ...     -1.0
# 17       /@scottsreality   True                     ...     -1.0
# 18         /@bretmanrock   True                     ...     -1.0
# 19            /@overtime   True                     ...     -1.0
# 20         /@brookemonk_   True                     ...     -1.0
# 21      /@northeasterner   True                     ...     -1.0
# 22         /@jack.wright   True                     ...     -1.0
# 23            /@itsavage   True                     ...     -1.0
# 24      /@barstoolsports   True                     ...     -1.0
# 25  /@jayprehistoricpets   True                     ...     -1.0
# 26             /@garyvee   True                     ...     -1.0
# 27              /@tiktok   True                     ...     -1.0
# 28       /@abbieherbert_   True                     ...     -1.0
# 29        /@wren.eleanor   True                     ...     -1.0
#
#                  userId       likes challengeId         fans verified posts  \
# 0               5831967  9400000000        None  117200000.0     True   NaN
# 1   6748458643983238149  1600000000        None   72000000.0     True   NaN
# 2   6703550784929793030  5200000000        None   80900000.0     True   NaN
# 3   6780564068844880902   295700000        None   23400000.0     True   NaN
# 4   6739078402710553605   220800000        None   12500000.0     True   NaN
# 5   6654362767867265030   372600000        None   32300000.0     True   NaN
# 6   6663294979903422470  1100000000        None   16600000.0     True   NaN
# 7   6813630187164533765   904300000        None   14400000.0     True   NaN
# 8   6669716864531054598   336400000        None   12100000.0     True   NaN
# 9   6905042173626008581    67700000        None    6600000.0    False   NaN
# 10  6879693940111901701   130600000        None   30400000.0     True   NaN
# 11    84635664075374592   496500000        None   16100000.0     True   NaN
# 12  6957597538883142661    65500000        None    6000000.0    False   NaN
# 13  6544081646253342726   191100000        None    7200000.0    False   NaN
# 14  6746417382892176389   759000000        None   18400000.0     True   NaN
# 15              7239462   445500000        None   17600000.0     True   NaN
# 16  6775033566016963589  1700000000        None   27400000.0     True   NaN
# 17  6718992235998741510   446900000        None   24300000.0     True   NaN
# 18              1180651   217900000        None   11400000.0     True   NaN
# 19  6625714545389142022  1200000000        None   16800000.0     True   NaN
# 20  6732675975610074118  1100000000        None   15500000.0     True   NaN
# 21  6904838098921440262    81300000        None    5500000.0    False   NaN
# 22              9881080   384600000        None    8500000.0     True   NaN
# 23    91752822198640640   297600000        None   12600000.0     True   NaN
# 24  6646764999833403398   849900000        None   13600000.0     True   NaN
# 25  6699542567460389894   173200000        None   13500000.0     True   NaN
# 26             17309235   218400000        None    6600000.0     True   NaN
# 27               107955   253400000        None   54400000.0     True   NaN
# 28  6767527973299536901   646000000        None    8800000.0     True   NaN
# 29  6716859375102870533   274600000        None   11000000.0    False   NaN
#
#    musicId  challengeName roomId
# 0     None           None
# 1     None           None
# 2     None           None
# 3     None           None
# 4     None           None
# 5     None           None
# 6     None           None
# 7     None           None
# 8     None           None
# 9     None           None
# 10    None           None
# 11    None           None
# 12    None           None
# 13    None           None
# 14    None           None
# 15    None           None
# 16    None           None
# 17    None           None
# 18    None           None
# 19    None           None
# 20    None           None
# 21    None           None
# 22    None           None
# 23    None           None
# 24    None           None
# 25    None           None
# 26    None           None
# 27    None           None
# 28    None           None
# 29    None           None
#
# [30 rows x 24 columns]

# %%
users = users_df.drop(columns=
              ['playToken', 
               'keyToken', 
               'type',
               'link', 
               'round',
               'extraInfo',
               'roomId',
                'relation',
                'challengeId',
                'musicId',
                'posts',
                'secUid',
                'userId',
                'challengeName',
                'views',
                'playUrl'])
users
# Out:
#                      id                                              cover  \
# 0               5831967  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 1   6748458643983238149  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 2   6703550784929793030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 3   6780564068844880902  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   6739078402710553605  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 5   6654362767867265030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   6663294979903422470  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 7   6813630187164533765  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   6669716864531054598  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 9   6905042173626008581  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 10  6879693940111901701  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11    84635664075374592  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 12  6957597538883142661  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  6544081646253342726  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 14  6746417382892176389  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 15              7239462  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  6775033566016963589  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 17  6718992235998741510  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 18              1180651  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  6625714545389142022  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  6732675975610074118  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 21  6904838098921440262  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22              9881080  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 23    91752822198640640  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 24  6646764999833403398  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  6699542567460389894  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 26             17309235  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27               107955  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  6767527973299536901  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 29  6716859375102870533  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
#
#                 title             subTitle  \
# 0     charli d’amelio       @charlidamelio
# 1        Bella Poarch         @bellapoarch
# 2         addison rae           @addisonre
# 3         Mia Khalifa          @miakhalifa
# 4   Dr. Daniel Aronov     @dr.danielaronov
# 5       Kylie Jenner          @kyliejenner
# 6                ESPN                @espn
# 7           siennamae           @siennamae
# 8     Brody Wellmaker      @brodywellmaker
# 9         Monkey keer          @monkeykeer
# 10      BILLIE EILISH        @billieeilish
# 11              lizzo               @lizzo
# 12     LIGHTS ARE OFF      @lights.are.off
# 13                 Ri               @riwww
# 14          KEEMOKAZI           @keemokazi
# 15       Malu Trevejo         @malutrevejo
# 16          noah beck            @noahbeck
# 17            Scott 🔥       @scottsreality
# 18        bretmanrock         @bretmanrock
# 19           Overtime            @overtime
# 20        Brooke Monk         @brookemonk_
# 21     northeasterner      @northeasterner
# 22        jack wright         @jack.wright
# 23           Savage 😈            @itsavage
# 24    Barstool Sports      @barstoolsports
# 25         Jay Brewer  @jayprehistoricpets
# 26   Gary Vaynerchuk              @garyvee
# 27             TikTok              @tiktok
# 28       AbbieHerbert       @abbieherbert_
# 29   Wren & Jacquelyn        @wren.eleanor
#
#                                           description       likes  \
# 0                                                      9400000000
# 1                  BUILD A BITCH MUSIC VIDEO OUT NOW😈  1600000000
# 2                      OBSESSED out on all platforms.  5200000000
# 3        Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co   295700000
# 4   See ALL my surgeries on my Instagram! INQUIRIE...   220800000
# 5                The official account of Kylie Jenner   372600000
# 6                       You won’t regret following! 🔥  1100000000
# 7                   I’ll be famous one day\nceo of 🐿💨   904300000
# 8   Trying to sneak my way into Hollywood 🤫 \nbrod...   336400000
# 9                Thanks to all friends who follow me.    67700000
# 10                                                 19   130600000
# 11                                    100% that bitch   496500000
# 12  LIGHTS ARE OFF\nI bring nightmares to life eve...    65500000
# 13  I’m Renata. 18\nthx 7m \ninsta: @ri.www\nRi.co...   191100000
# 14  Following back on IG for the next 24 hours ↖️🔥...   759000000
# 15                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋   445500000
# 16  ur luv’d<3\ndo what makes you happy\nbusiness:...  1700000000
# 17  Donating to new IG followers!💰 \n📧 Scott@grail...   446900000
# 18                                             legend   217900000
# 19  Best page in the galaxy 💫\nThanks for being my...  1200000000
# 20  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...  1100000000
# 21                 Follow me to watch more food video    81300000
# 22                spread positivity😁\nfollow the gram   384600000
# 23  CEO Of It Works 😃👍\n-\nBuisness - HendrickGold...   297600000
# 24          🗣 Viva La Stool\n\nGoing viral is a sport   849900000
# 25  Sub to my YouTube for even more animal fun see...   173200000
# 26  🔑 Entrepreneur\n🔮 Investor in Uber, Snap, Venm...   218400000
# 27                                It Starts On TikTok   253400000
# 28  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...   646000000
# 29  Wren PO Box 461243 Papillion, NE 68046 📬\nteam...   274600000
#
#            fans verified
# 0   117200000.0     True
# 1    72000000.0     True
# 2    80900000.0     True
# 3    23400000.0     True
# 4    12500000.0     True
# 5    32300000.0     True
# 6    16600000.0     True
# 7    14400000.0     True
# 8    12100000.0     True
# 9     6600000.0    False
# 10   30400000.0     True
# 11   16100000.0     True
# 12    6000000.0    False
# 13    7200000.0    False
# 14   18400000.0     True
# 15   17600000.0     True
# 16   27400000.0     True
# 17   24300000.0     True
# 18   11400000.0     True
# 19   16800000.0     True
# 20   15500000.0     True
# 21    5500000.0    False
# 22    8500000.0     True
# 23   12600000.0     True
# 24   13600000.0     True
# 25   13500000.0     True
# 26    6600000.0     True
# 27   54400000.0     True
# 28    8800000.0     True
# 29   11000000.0    False

# %%
users['title'] = users['title'].str.title()

# %%
users_clean = users.rename(columns={
    'id': 'User ID',
    'cover': "User's Cover Picture",
    'title': "User's Name",
    'subTitle': "User's Handle",
    'description': 'Description',
    'fans': 'Followers',
    'verified': 'Verified',
    'likes': 'Likes'
})
users_clean
# Out:
#                 User ID                               User's Cover Picture  \
# 0               5831967  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 1   6748458643983238149  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 2   6703550784929793030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 3   6780564068844880902  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   6739078402710553605  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 5   6654362767867265030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   6663294979903422470  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 7   6813630187164533765  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   6669716864531054598  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 9   6905042173626008581  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 10  6879693940111901701  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11    84635664075374592  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 12  6957597538883142661  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  6544081646253342726  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 14  6746417382892176389  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 15              7239462  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  6775033566016963589  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 17  6718992235998741510  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 18              1180651  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  6625714545389142022  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  6732675975610074118  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 21  6904838098921440262  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22              9881080  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 23    91752822198640640  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 24  6646764999833403398  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  6699542567460389894  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 26             17309235  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27               107955  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  6767527973299536901  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 29  6716859375102870533  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
#
#           User's Name        User's Handle  \
# 0     Charli D’Amelio       @charlidamelio
# 1        Bella Poarch         @bellapoarch
# 2         Addison Rae           @addisonre
# 3         Mia Khalifa          @miakhalifa
# 4   Dr. Daniel Aronov     @dr.danielaronov
# 5       Kylie Jenner          @kyliejenner
# 6                Espn                @espn
# 7           Siennamae           @siennamae
# 8     Brody Wellmaker      @brodywellmaker
# 9         Monkey Keer          @monkeykeer
# 10      Billie Eilish        @billieeilish
# 11              Lizzo               @lizzo
# 12     Lights Are Off      @lights.are.off
# 13                 Ri               @riwww
# 14          Keemokazi           @keemokazi
# 15       Malu Trevejo         @malutrevejo
# 16          Noah Beck            @noahbeck
# 17            Scott 🔥       @scottsreality
# 18        Bretmanrock         @bretmanrock
# 19           Overtime            @overtime
# 20        Brooke Monk         @brookemonk_
# 21     Northeasterner      @northeasterner
# 22        Jack Wright         @jack.wright
# 23           Savage 😈            @itsavage
# 24    Barstool Sports      @barstoolsports
# 25         Jay Brewer  @jayprehistoricpets
# 26   Gary Vaynerchuk              @garyvee
# 27             Tiktok              @tiktok
# 28       Abbieherbert       @abbieherbert_
# 29   Wren & Jacquelyn        @wren.eleanor
#
#                                           Description       Likes  \
# 0                                                      9400000000
# 1                  BUILD A BITCH MUSIC VIDEO OUT NOW😈  1600000000
# 2                      OBSESSED out on all platforms.  5200000000
# 3        Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co   295700000
# 4   See ALL my surgeries on my Instagram! INQUIRIE...   220800000
# 5                The official account of Kylie Jenner   372600000
# 6                       You won’t regret following! 🔥  1100000000
# 7                   I’ll be famous one day\nceo of 🐿💨   904300000
# 8   Trying to sneak my way into Hollywood 🤫 \nbrod...   336400000
# 9                Thanks to all friends who follow me.    67700000
# 10                                                 19   130600000
# 11                                    100% that bitch   496500000
# 12  LIGHTS ARE OFF\nI bring nightmares to life eve...    65500000
# 13  I’m Renata. 18\nthx 7m \ninsta: @ri.www\nRi.co...   191100000
# 14  Following back on IG for the next 24 hours ↖️🔥...   759000000
# 15                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋   445500000
# 16  ur luv’d<3\ndo what makes you happy\nbusiness:...  1700000000
# 17  Donating to new IG followers!💰 \n📧 Scott@grail...   446900000
# 18                                             legend   217900000
# 19  Best page in the galaxy 💫\nThanks for being my...  1200000000
# 20  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...  1100000000
# 21                 Follow me to watch more food video    81300000
# 22                spread positivity😁\nfollow the gram   384600000
# 23  CEO Of It Works 😃👍\n-\nBuisness - HendrickGold...   297600000
# 24          🗣 Viva La Stool\n\nGoing viral is a sport   849900000
# 25  Sub to my YouTube for even more animal fun see...   173200000
# 26  🔑 Entrepreneur\n🔮 Investor in Uber, Snap, Venm...   218400000
# 27                                It Starts On TikTok   253400000
# 28  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...   646000000
# 29  Wren PO Box 461243 Papillion, NE 68046 📬\nteam...   274600000
#
#       Followers Verified
# 0   117200000.0     True
# 1    72000000.0     True
# 2    80900000.0     True
# 3    23400000.0     True
# 4    12500000.0     True
# 5    32300000.0     True
# 6    16600000.0     True
# 7    14400000.0     True
# 8    12100000.0     True
# 9     6600000.0    False
# 10   30400000.0     True
# 11   16100000.0     True
# 12    6000000.0    False
# 13    7200000.0    False
# 14   18400000.0     True
# 15   17600000.0     True
# 16   27400000.0     True
# 17   24300000.0     True
# 18   11400000.0     True
# 19   16800000.0     True
# 20   15500000.0     True
# 21    5500000.0    False
# 22    8500000.0     True
# 23   12600000.0     True
# 24   13600000.0     True
# 25   13500000.0     True
# 26    6600000.0     True
# 27   54400000.0     True
# 28    8800000.0     True
# 29   11000000.0    False

# %%
users_clean.to_csv('users_data1.csv')

# %%
hashtags_df = parsed_df[parsed_df['type'] == 3]
hashtags_df
# Out:
#                   id  type                                              cover  \
# 29            400318     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 30  1647119754150918     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 31  1662027712917510     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 32  1637138684632070     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 33  1587934459506690     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 34             27892     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 35  1596232738661382     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 36           4174123     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 37          12106204     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 38          15290423     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
#
#                  title      subTitle  \
# 29          #buffering  443.8M views
# 30  #tiktokmademebuyit    2.8B views
# 31       #prideanthems   38.1M views
# 32       #foryourpride  466.2M views
# 33          #tiktokart    5.8B views
# 34        #memorialday  830.9M views
# 35     #dreamaesthetic  143.4M views
# 36        #classof2021    1.3B views
# 37        #todayislove  288.1M views
# 38           #uclfinal  530.9M views
#
#                                           description                    link  \
# 29  Use our Creative Effect and show us what happe...          /tag/buffering
# 30  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 31  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 32  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 33  From painters to sculptures and everything in ...          /tag/tiktokart
# 34                        Commemorating #MemorialDay.        /tag/memorialday
# 35                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 36  Whether you're celebrating online or just part...        /tag/classof2021
# 37                       #TodayIsLove! We love today.        /tag/todayislove
# 38  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#     round playToken keyToken  ... relation       challengeId  musicId posts  \
# 29  False                     ...      NaN            400318     None   NaN
# 30  False                     ...      NaN  1647119754150918     None   NaN
# 31  False                     ...      NaN  1662027712917510     None   NaN
# 32  False                     ...      NaN  1637138684632070     None   NaN
# 33  False                     ...      NaN  1587934459506690     None   NaN
# 34  False                     ...      NaN             27892     None   NaN
# 35  False                     ...      NaN  1596232738661382     None   NaN
# 36  False                     ...      NaN           4174123     None   NaN
# 37  False                     ...      NaN          12106204     None   NaN
# 38  False                     ...      NaN          15290423     None   NaN
#
#     likes secUid userId      challengeName       views playUrl
# 29   None   None   None          buffering   443800000    None
# 30   None   None   None  tiktokmademebuyit  2800000000    None
# 31   None   None   None       prideanthems    38100000    None
# 32   None   None   None       foryourpride   466200000    None
# 33   None   None   None          tiktokart  5800000000    None
# 34   None   None   None        memorialday   830900000    None
# 35   None   None   None     dreamaesthetic   143400000    None
# 36   None   None   None        classof2021  1300000000    None
# 37   None   None   None        todayislove   288100000    None
# 38   None   None   None           uclfinal   530900000    None
#
# [10 rows x 24 columns]

# %%
def parse_number(num: str) -> int:
    videos = num.split()[0]
    number = videos[:-1]
    units = videos[-1]
    units_mapper = {
        "K": 1,
        "M": 1000,
        "B": 1000000
    }
    return (float(number)) * float(units_mapper.get(units))

# %%
df = pd.DataFrame(hashtags_df['subTitle'])
df
# Out:
#         subTitle
# 29  443.8M views
# 30    2.8B views
# 31   38.1M views
# 32  466.2M views
# 33    5.8B views
# 34  830.9M views
# 35  143.4M views
# 36    1.3B views
# 37  288.1M views
# 38  530.9M views

# %%
df['videos_count'] = df['subTitle'].apply(parse_number)
df
# Out:
#         subTitle  videos_count
# 29  443.8M views      443800.0
# 30    2.8B views     2800000.0
# 31   38.1M views       38100.0
# 32  466.2M views      466200.0
# 33    5.8B views     5800000.0
# 34  830.9M views      830900.0
# 35  143.4M views      143400.0
# 36    1.3B views     1300000.0
# 37  288.1M views      288100.0
# 38  530.9M views      530900.0

# %%
hashtag_merged = pd.merge(hashtags_df, df).drop(columns=
                                                ['subTitle', 
                                                 'cover', 
                                                 'round', 
                                                 'keyToken', 
                                                 'playToken', 
                                                 'extraInfo', 
                                                 'type',
                                                 'extraInfo',
                                                 'roomId',
                                                 'relation',
                                                 'challengeId',
                                                 'musicId',
                                                 'posts',
                                                 'secUid',
                                                 'userId',
                                                 'challengeName',
                                                 'views',
                                                 'playUrl',
                                                 'fans',
                                                 'verified',
                                                 'likes'
                                                ])
hashtag_merged
# Out:
#                  id               title  \
# 0            400318          #buffering
# 1  1647119754150918  #tiktokmademebuyit
# 2  1662027712917510       #prideanthems
# 3  1637138684632070       #foryourpride
# 4  1587934459506690          #tiktokart
# 5             27892        #memorialday
# 6  1596232738661382     #dreamaesthetic
# 7           4174123        #classof2021
# 8          12106204        #todayislove
# 9          15290423           #uclfinal
#
#                                          description                    link  \
# 0  Use our Creative Effect and show us what happe...          /tag/buffering
# 1  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 2  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 3  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 4  From painters to sculptures and everything in ...          /tag/tiktokart
# 5                        Commemorating #MemorialDay.        /tag/memorialday
# 6                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 7  Whether you're celebrating online or just part...        /tag/classof2021
# 8                       #TodayIsLove! We love today.        /tag/todayislove
# 9  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#    videos_count
# 0      443800.0
# 1     2800000.0
# 2       38100.0
# 3      466200.0
# 4     5800000.0
# 5      830900.0
# 6      143400.0
# 7     1300000.0
# 8      288100.0
# 9      530900.0

# %%
hashtag_clean = hashtag_merged.rename(columns={
    'id': 'Hashtag ID',
    'title': 'Hashtag',
    'description': 'Description',
    'link': 'Link to Trend Page',
    'videos_count': 'Number of Videos with Hashtag (in Thousands)',
})
hashtag_clean
# Out:
#          Hashtag ID             Hashtag  \
# 0            400318          #buffering
# 1  1647119754150918  #tiktokmademebuyit
# 2  1662027712917510       #prideanthems
# 3  1637138684632070       #foryourpride
# 4  1587934459506690          #tiktokart
# 5             27892        #memorialday
# 6  1596232738661382     #dreamaesthetic
# 7           4174123        #classof2021
# 8          12106204        #todayislove
# 9          15290423           #uclfinal
#
#                                          Description      Link to Trend Page  \
# 0  Use our Creative Effect and show us what happe...          /tag/buffering
# 1  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 2  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 3  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 4  From painters to sculptures and everything in ...          /tag/tiktokart
# 5                        Commemorating #MemorialDay.        /tag/memorialday
# 6                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 7  Whether you're celebrating online or just part...        /tag/classof2021
# 8                       #TodayIsLove! We love today.        /tag/todayislove
# 9  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#    Number of Videos with Hashtag (in Thousands)
# 0                                      443800.0
# 1                                     2800000.0
# 2                                       38100.0
# 3                                      466200.0
# 4                                     5800000.0
# 5                                      830900.0
# 6                                      143400.0
# 7                                     1300000.0
# 8                                      288100.0
# 9                                      530900.0

# %%
hashtag_clean.to_csv('hashtag_data.csv')

# %%
import requests

url = "https://tik-tok-feed.p.rapidapi.com/"

querystring = {"search":"6968387127449012994","type":"music-feed","max":"0"}

headers = {
    'x-rapidapi-key': "4c74301b08msh16e7070111b8497p1a6cb4jsn13f4d5f28255",
    'x-rapidapi-host': "tik-tok-feed.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}
