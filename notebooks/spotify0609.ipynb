# %%
import pandas as pd

# %%
spotify = pd.read_csv('../spotify_data/spotify0609.csv', header=1)
spotify
# Out:
#      Position                         Track Name                   Artist  \
# 0           1                           good 4 u           Olivia Rodrigo
# 1           2                         Todo De Ti           Rauw Alejandro
# 2           3                           Yonaguni                Bad Bunny
# 3           4     MONTERO (Call Me By Your Name)                Lil Nas X
# 4           5                             Butter                      BTS
# ..        ...                                ...                      ...
# 195       196                               Dior                Pop Smoke
# 196       197           Something Just Like This         The Chainsmokers
# 197       198  Stereo Hearts (feat. Adam Levine)         Gym Class Heroes
# 198       199   Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 199       200        Godzilla (feat. Juice WRLD)                   Eminem
#
#      Streams                                                URL
# ...

# %%
sptify_cleaned = spotify.sort_values(by='Streams', ascending=False).head(9).drop(columns=['Position', 'URL'])
sptify_cleaned
# Out:
#                                Track Name          Artist  Streams
# 0                                good 4 u  Olivia Rodrigo  9756087
# 1                              Todo De Ti  Rauw Alejandro  6359382
# 2                                Yonaguni       Bad Bunny  6303435
# 3          MONTERO (Call Me By Your Name)       Lil Nas X  5038190
# 4                                  Butter             BTS  4912494
# 5                Kiss Me More (feat. SZA)        Doja Cat  4850457
# 6                                 deja vu  Olivia Rodrigo  4785146
# 7  Peaches (feat. Daniel Caesar & Giveon)   Justin Bieber  3983335
# 8               Levitating (feat. DaBaby)        Dua Lipa  3966943

# %%
sptify_cleaned.to_csv('../spotify_data/spotify_top_songs.csv')
