# %%
import requests

url = "https://tiktok-trending-data.p.rapidapi.com/t"

headers = {
    'x-rapidapi-key': "86012d1ee8msh9e6fcf09224f8e6p185a74jsn60c6b9ca1ca2",
    'x-rapidapi-host': "tiktok-trending-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"statusCode":0,"body":[{"pageState":{},"exploreList":[{"cardItem":{"id":"6748458643983238149","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/01d747eeb63f0cef2cc05a0099ab74e3~c5_100x100.jpeg?x-expires=1622862000&x-signature=z%2B7lgT7KXG1ZVWdWlVV%2Fmiijz5Y%3D","title":"Bella Poarch","subTitle":"@bellapoarch","description":"BUILD A BITCH MUSIC VIDEO OUT NOW😈","link":"/@bellapoarch","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":71400000,"likes":"1600000000","userId":"6748458643983238149","secUid":"MS4wLjABAAAAIQGNoHByQvokcLbWCGnIfas0OV2nctsZnRFbN7eB04xt-9usrHe3UvXJRZLxBWlJ","relation":-1,"roomId":""}}},{"cardItem":{"id":"5831967","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/0a0242e5f906bf9301f859c568b5ecc4~c5_100x100.jpeg?x-expires=1622862000&x-signature=e4SAi3KVZ5ervw1NyqSc%2BblX%2FSM%3D","title":"charli d’amelio","subTitle":"@charlidamelio","description":"","link":"/@charlidamelio","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":116900000,"likes":"9400000000","userId":"5831967","secUid":"MS4wLjABAAAA-VASjiXTh7wDDyXvjk10VFhMWUAoxr8bgfO1kAL1-9s","relation":-1,"roomId":""}}},{"cardItem":{"id":"6739078402710553605","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1658853392415749~c5_100x100.jpeg?x-expires=1622862000&x-signature=XTME3djP0uM9iv3Cm58LizZCBYs%3D","title":"Dr. Daniel Aronov","subTitle":"@dr.danielaronov","description":"See ALL my surgeries on my Instagram! INQUIRIES? 👉 DM me on Instagram","link":"/@dr.danielaronov","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":12300000,"likes":"214900000","userId":"6739078402710553605","secUid":"MS4wLjABAAAADfrPcyWFROfYl4vfjYJ9_g4hCUwaNqG-FCm83dbOgohdee8YSlFv0H8rs6SOkKUZ","relation":-1,"roomId":""}}},{"cardItem":{"id":"6727327145951183878","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1646315618666501~c5_100x100.jpeg?x-expires=1622862000&x-signature=qyZGsiPkKiePWBZImvyHH4%2FtgjA%3D","title":"Will Smith","subTitle":"@willsmith","description":"Same kid from West Philly.","link":"/@willsmith","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":54900000,"likes":"332500000","userId":"6727327145951183878","secUid":"MS4wLjABAAAA8ezUaW4ecJX222ObGXxt07F9BIh4QH3-g1P1DHyChT2LLi2cn-vAE2R53-H672ZO","relation":-1,"roomId":""}}},{"cardItem":{"id":"6703550784929793030","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/69e3328223da5577e78ce7f33729c2dd~c5_100x100.jpeg?x-expires=1622862000&x-signature=WG%2Fh6Pvu7LckhqWDP1ff0MF6r7Y%3D","title":"addison rae","subTitle":"@addisonre","description":"OBSESSED out on all platforms.","link":"/@addisonre","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":80800000,"likes":"5200000000","userId":"6703550784929793030","secUid":"MS4wLjABAAAAVjQK614JSGmZVT3EVAiSDfznaBJOVfWPrtqDsQ9YxU368ewQrTyyEOb3OtJb4xCI","relation":-1,"roomId":""}}},{"cardItem":{"id":"6587535917023182853","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/22119f863eae7e35852cdf7b41efe20a~c5_100x100.jpeg?x-expires=1622862000&x-signature=9Oj%2BUNmmNbt3aMuYqTKcXaGvpI0%3D","title":"Daniel LaBelle","subTitle":"@daniel.labelle","description":"","link":"/@daniel.labelle","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":true,"fans":19700000,"likes":"421600000","userId":"6587535917023182853","secUid":"MS4wLjABAAAA2sCfGnqRN1c0jn5CxmbkNDWyI39XImwnfb_IJQGE1i-cRUcgSJv_un0Cje3g39Mn","relation":-1,"roomId":""}}},{"cardItem":{"id":"6669716864531054598","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/9cb32fc5f2def0dc269a28f3af700861~c5_100x100.jpeg?x-expires=1622862000&x-signature=o1g8M5v73Ixoo3FKwLDGGEo0D%2B0%3D","title":"Brody Wellmaker","subTitle":"@brodywellmaker","description":"Trying to sneak my way into Hollywood 🤫 \nbrodywellmaker@viralnationtalent.com","link":"/@brodywellmaker"," ...

# %%
import json
import pandas as pd
trending_json = json.loads(response.text)

# %%
parsed_data = {
    "id": [],
    "type": [],
    "cover": [],
    "title": [],
    "subTitle": [],
    "description": [],
    "link": [],
    "round": [],
    "playToken": [],
    "keyToken": [],
    "extraInfo": []
}

# %%
for type_result in trending_json["body"]:
    for item in type_result["exploreList"]:
        for k in item["cardItem"].keys():
                val = item["cardItem"].get(k)
                #print(val)
                parsed_data.get(k).append(val)

# %%
parsed_df = pd.DataFrame(parsed_data)
parsed_df
# Out:
#                      id  type  \
# 0   6748458643983238149     2
# 1               5831967     2
# 2   6739078402710553605     2
# 3   6727327145951183878     2
# 4   6703550784929793030     2
# 5   6587535917023182853     2
# 6   6669716864531054598     2
# 7   6699542567460389894     2
# 8   6663294979903422470     2
# 9     84635664075374592     2
# 10  6654362767867265030     2
# 11              7239462     2
# 12  6904838098921440262     2
# 13  6718992235998741510     2
# 14  6813630187164533765     2
# 15  6625714545389142022     2
# 16  6544081646253342726     2
# 17  6757817457937499141     2
# 18  6732675975610074118     2
# 19  6767527973299536901     2
# 20  6781939622308037638     2
# 21              1180651     2
# 22  6763517179218330630     2
# 23  6695492574909613061     2
# 24  6780564068844880902     2
# 25  6658722935124328453     2
# 26  6746417382892176389     2
# 27  6646764999833403398     2
# 28  6957597538883142661     2
# 29               400318     3
# 30     1647119754150918     3
# 31     1662027712917510     3
# 32     1637138684632070     3
# 33     1587934459506690     3
# 34                27892     3
# 35     1596232738661382     3
# 36              4174123     3
# 37             12106204     3
# 38             15290423     3
# 39  6808287098886424577     1
# 40  6812545347835922434     1
# 41  6807966889273346822     1
# 42  6813134956269947654     1
# 43  6827517892439968517     1
# 44  6834110584288447237     1
# 45  6754420279457565445     1
# 46  6746993352891189249     1
# 47  6691366574592396038     1
#
#                                                 cover  \
# 0   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 1   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 2   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 3   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 5   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 7   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 9   https://p16-sign-va.tiktokcdn.com/musically-ma...
# 10  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 12  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 14  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 15  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 17  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 18  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 23  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 24  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 29  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 30  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 31  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 32  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 33  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 34  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 35  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 36  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 37  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 38  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 39  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 40  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 41  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 42  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 43  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 44  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 45  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 46  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 47  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
#
#                                title             subTitle  \
# 0                       Bella Poarch         @bellapoarch
# 1                    charli d’amelio       @charlidamelio
# 2                  Dr. Daniel Aronov     @dr.danielaronov
# 3                         Will Smith           @willsmith
# 4                        addison rae           @addisonre
# 5                     Daniel LaBelle      @daniel.labelle
# 6                    Brody Wellmaker      @brodywellmaker
# 7                         Jay Brewer  @jayprehistoricpets
# 8                               ESPN                @espn
# 9                              lizzo               @lizzo
# 10                     Kylie Jenner          @kyliejenner
# 11                      Malu Trevejo         @malutrevejo
# 12                    northeasterner      @northeasterner
# 13                           Scott 🔥       @scottsreality
# 14                         siennamae           @siennamae
# 15                          Overtime            @overtime
# 16                                Ri               @riwww
# 17                      Tooturnttony        @tooturnttony
# 18                       Brooke Monk         @brookemonk_
# 19                      AbbieHerbert       @abbieherbert_
# 20                        Jack Black           @jackblack
# 21                       bretmanrock         @bretmanrock
# 22                     otakoyakisoba       @otakoyakisoba
# 23                           choctiv             @choctiv
# 24                       Mia Khalifa          @miakhalifa
# 25                         lil nas x             @lilnasx
# 26                         KEEMOKAZI           @keemokazi
# 27                   Barstool Sports      @barstoolsports
# 28                    LIGHTS ARE OFF      @lights.are.off
# 29                        #buffering         443.8M views
# 30                #tiktokmademebuyit           2.8B views
# 31                     #prideanthems          38.1M views
# 32                     #foryourpride         466.2M views
# 33                        #tiktokart           5.8B views
# 34                      #memorialday         830.9M views
# 35                   #dreamaesthetic         143.4M views
# 36                      #classof2021           1.3B views
# 37                      #todayislove         288.1M views
# 38                         #uclfinal         530.9M views
# 39  Then Leave (feat. Queendom Come)          1.1M videos
# 40                         Hood Baby          2.9M videos
# 41                        Dream Girl         13.5M videos
# 42    Stunnin' (feat. Harm Franklin)          1.1M videos
# 43                             Do It        468.3K videos
# 44  Savage Love (Laxed - Siren Beat)          785K videos
# 45                      Mr. Blue Sky        546.8K videos
# 46          Monkeys Spinning Monkeys          9.9M videos
# 47            Woah (feat. D3Mstreet)         12.4M videos
#
#                                           description  \
# 0                  BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 1
# 2   See ALL my surgeries on my Instagram! INQUIRIE...
# 3                          Same kid from West Philly.
# 4                      OBSESSED out on all platforms.
# 5
# 6   Trying to sneak my way into Hollywood 🤫 \nbrod...
# 7   Sub to my YouTube for even more animal fun see...
# 8                       You won’t regret following! 🔥
# 9                                     100% that bitch
# 10               The official account of Kylie Jenner
# 11                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋
# 12                 Follow me to watch more food video
# 13  Donating to new IG followers!💰 \n📧 Scott@grail...
# 14                  I’ll be famous one day\nceo of 🐿💨
# 15  Best page in the galaxy 💫\nThanks for being my...
# 16  I’m Renata. 18\nthx 6m \ninsta: @ri.www\nRi.co...
# 17           DM me on Connected2me! \nDownload here 👇
# 18  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...
# 19  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...
# 20
# 21                                             legend
# 22  Olly & Mama LuLu\nYour favorite Mother & Son d...
# 23  INSTA: @choctiv 😈\nLIL EINSTEIN OUT NOW ! 🚀💫\n...
# 24       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co
# 25  “MONTERO (CALL ME BY YOUR NAME)” & “SUN GOES D...
# 26  Following back on IG for the next 24 hours ↖️🔥...
# 27          🗣 Viva La Stool\n\nGoing viral is a sport
# 28  LIGHTS ARE OFF\nI bring nightmares to life eve...
# 29  Use our Creative Effect and show us what happe...
# 30  Whether you're still hunting for feta cheese o...
# 31  Whether it's an iconic bop that's been an esse...
# 32  Pride Month is here, and TikTok is celebrating...
# 33  From painters to sculptures and everything in ...
# 34                        Commemorating #MemorialDay.
# 35                       What's your #DreamAesthetic?
# 36  Whether you're celebrating online or just part...
# 37                       #TodayIsLove! We love today.
# 38  The 2020/21 Champions League final is here! Us...
# 39                                           BeatKing
# 40                                               Kbfr
# 41                                            Ir Sais
# 42                                      Curtis Waters
# 43                                      Chloe x Halle
# 44                           Jawsh 685 & Jason Derulo
# 45                           Electric Light Orchestra
# 46                                      Kevin MacLeod
# 47                                         KRYPTO9095
#
#                                                  link  round playToken  \
# 0                                       /@bellapoarch   True
# 1                                     /@charlidamelio   True
# 2                                   /@dr.danielaronov   True
# 3                                         /@willsmith   True
# 4                                         /@addisonre   True
# 5                                    /@daniel.labelle   True
# 6                                    /@brodywellmaker   True
# 7                                /@jayprehistoricpets   True
# 8                                              /@espn   True
# 9                                             /@lizzo   True
# 10                                      /@kyliejenner   True
# 11                                      /@malutrevejo   True
# 12                                   /@northeasterner   True
# 13                                    /@scottsreality   True
# 14                                        /@siennamae   True
# 15                                         /@overtime   True
# 16                                            /@riwww   True
# 17                                     /@tooturnttony   True
# 18                                      /@brookemonk_   True
# 19                                    /@abbieherbert_   True
# 20                                        /@jackblack   True
# 21                                      /@bretmanrock   True
# 22                                    /@otakoyakisoba   True
# 23                                          /@choctiv   True
# 24                                       /@miakhalifa   True
# 25                                          /@lilnasx   True
# 26                                        /@keemokazi   True
# 27                                   /@barstoolsports   True
# 28                                   /@lights.are.off   True
# 29                                     /tag/buffering  False
# 30                             /tag/tiktokmademebuyit  False
# 31                                  /tag/prideanthems  False
# 32                                  /tag/foryourpride  False
# 33                                     /tag/tiktokart  False
# 34                                   /tag/memorialday  False
# 35                                /tag/dreamaesthetic  False
# 36                                   /tag/classof2021  False
# 37                                   /tag/todayislove  False
# 38                                      /tag/uclfinal  False
# 39  /music/Then-Leave-feat-Queendom-Come-680828709...  False
# 40               /music/Hood-Baby-6812545347835922434  False
# 41              /music/Dream-Girl-6807966889273346822  False
# 42  /music/Stunnin-feat-Harm-Franklin-681313495626...  False
# 43                   /music/Do-It-6827517892439968517  False
# 44  /music/Savage-Love-Laxed-Siren-Beat-6834110584...  False
# 45             /music/Mr-Blue-Sky-6754420279457565445  False
# 46  /music/Monkeys-Spinning-Monkeys-67469933528911...  False
# 47     /music/Woah-feat-D3Mstreet-6691366574592396038  False
#
#    keyToken                                          extraInfo
# 0            {'verified': True, 'fans': 71400000, 'likes': ...
# 1            {'verified': True, 'fans': 116900000, 'likes':...
# 2            {'verified': True, 'fans': 12300000, 'likes': ...
# 3            {'verified': True, 'fans': 54900000, 'likes': ...
# 4            {'verified': True, 'fans': 80800000, 'likes': ...
# 5            {'verified': True, 'fans': 19700000, 'likes': ...
# 6            {'verified': True, 'fans': 11800000, 'likes': ...
# 7            {'verified': True, 'fans': 13400000, 'likes': ...
# 8            {'verified': True, 'fans': 16400000, 'likes': ...
# 9            {'verified': True, 'fans': 16000000, 'likes': ...
# 10           {'verified': True, 'fans': 32100000, 'likes': ...
# 11           {'verified': True, 'fans': 17400000, 'likes': ...
# 12           {'verified': False, 'fans': 5300000, 'likes': ...
# 13           {'verified': True, 'fans': 24200000, 'likes': ...
# 14           {'verified': True, 'fans': 14600000, 'likes': ...
# 15           {'verified': True, 'fans': 16800000, 'likes': ...
# 16           {'verified': False, 'fans': 6900000, 'likes': ...
# 17           {'verified': True, 'fans': 8700000, 'likes': '...
# 18           {'verified': True, 'fans': 15400000, 'likes': ...
# 19           {'verified': True, 'fans': 8700000, 'likes': '...
# 20           {'verified': True, 'fans': 10200000, 'likes': ...
# 21           {'verified': True, 'fans': 11400000, 'likes': ...
# 22           {'verified': True, 'fans': 9200000, 'likes': '...
# 23           {'verified': True, 'fans': 4500000, 'likes': '...
# 24           {'verified': True, 'fans': 23100000, 'likes': ...
# 25           {'verified': True, 'fans': 16600000, 'likes': ...
# 26           {'verified': True, 'fans': 18300000, 'likes': ...
# 27           {'verified': True, 'fans': 13600000, 'likes': ...
# 28           {'verified': False, 'fans': 4900000, 'likes': ...
# 29           {'views': '443800000', 'challengeId': '400318'...
# 30           {'views': '2800000000', 'challengeId': '164711...
# 31           {'views': '38100000', 'challengeId': '16620277...
# 32           {'views': '466200000', 'challengeId': '1637138...
# 33           {'views': '5800000000', 'challengeId': '158793...
# 34           {'views': '830900000', 'challengeId': '27892',...
# 35           {'views': '143400000', 'challengeId': '1596232...
# 36           {'views': '1300000000', 'challengeId': '417412...
# 37           {'views': '288100000', 'challengeId': '1210620...
# 38           {'views': '530900000', 'challengeId': '1529042...
# 39           {'musicId': '6808287098886424577', 'playUrl': ...
# 40           {'musicId': '6812545347835922434', 'playUrl': ...
# 41           {'musicId': '6807966889273346822', 'playUrl': ...
# 42           {'musicId': '6813134956269947654', 'playUrl': ...
# 43           {'musicId': '6827517892439968517', 'playUrl': ...
# 44           {'musicId': '6834110584288447237', 'playUrl': ...
# 45           {'musicId': '6754420279457565445', 'playUrl': ...
# 46           {'musicId': '6746993352891189249', 'playUrl': ...
# 47           {'musicId': '6691366574592396038', 'playUrl': ...

# %%
extrainfo_keys = []

for info in parsed_df['extraInfo']:
    extrainfo_keys += (list(info.keys()))
extrainfo_keys = list(set(extrainfo_keys))
extrainfo_keys
# Out:
# ['roomId',
#  'fans',
#  'verified',
#  'relation',
#  'challengeId',
#  'musicId',
#  'posts',
#  'likes',
#  'secUid',
#  'userId',
#  'challengeName',
#  'views',
#  'playUrl']

# %%
for infokey in extrainfo_keys:
    parsed_df[infokey] = parsed_df['extraInfo'].apply(lambda x: x.get(infokey))
parsed_df.head()
# Out:
#                     id  type  \
# 0  6748458643983238149     2
# 1              5831967     2
# 2  6739078402710553605     2
# 3  6727327145951183878     2
# 4  6703550784929793030     2
#
#                                                cover              title  \
# 0  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Bella Poarch
# 1  https://p16-sign-va.tiktokcdn.com/musically-ma...    charli d’amelio
# 2  https://p16-sign-va.tiktokcdn.com/musically-ma...  Dr. Daniel Aronov
# 3  https://p16-sign-va.tiktokcdn.com/musically-ma...         Will Smith
# 4  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        addison rae
#
#            subTitle                                        description  \
# 0      @bellapoarch                 BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 1    @charlidamelio
# 2  @dr.danielaronov  See ALL my surgeries on my Instagram! INQUIRIE...
# 3        @willsmith                         Same kid from West Philly.
# 4        @addisonre                     OBSESSED out on all platforms.
#
#                 link  round playToken keyToken  ... relation challengeId  \
# 0      /@bellapoarch   True                     ...     -1.0        None
# 1    /@charlidamelio   True                     ...     -1.0        None
# 2  /@dr.danielaronov   True                     ...     -1.0        None
# 3        /@willsmith   True                     ...     -1.0        None
# 4        /@addisonre   True                     ...     -1.0        None
#
#    musicId posts       likes  \
# 0     None   NaN  1600000000
# 1     None   NaN  9400000000
# 2     None   NaN   214900000
# 3     None   NaN   332500000
# 4     None   NaN  5200000000
#
#                                               secUid               userId  \
# 0  MS4wLjABAAAAIQGNoHByQvokcLbWCGnIfas0OV2nctsZnR...  6748458643983238149
# 1  MS4wLjABAAAA-VASjiXTh7wDDyXvjk10VFhMWUAoxr8bgf...              5831967
# 2  MS4wLjABAAAADfrPcyWFROfYl4vfjYJ9_g4hCUwaNqG-FC...  6739078402710553605
# 3  MS4wLjABAAAA8ezUaW4ecJX222ObGXxt07F9BIh4QH3-g1...  6727327145951183878
# 4  MS4wLjABAAAAVjQK614JSGmZVT3EVAiSDfznaBJOVfWPrt...  6703550784929793030
#
#    challengeName views playUrl
# 0           None  None    None
# 1           None  None    None
# 2           None  None    None
# 3           None  None    None
# 4           None  None    None
#
# [5 rows x 24 columns]

# %%
music_df = parsed_df[parsed_df['type'] == 1]
music_df
# Out:
#                      id  type  \
# 39  6808287098886424577     1
# 40  6812545347835922434     1
# 41  6807966889273346822     1
# 42  6813134956269947654     1
# 43  6827517892439968517     1
# 44  6834110584288447237     1
# 45  6754420279457565445     1
# 46  6746993352891189249     1
# 47  6691366574592396038     1
#
#                                                 cover  \
# 39  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 40  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 41  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 42  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 43  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 44  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 45  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 46  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
# 47  https://p16-sg.tiktokcdn.com/aweme/100x100/tos...
#
#                                title       subTitle               description  \
# 39  Then Leave (feat. Queendom Come)    1.1M videos                  BeatKing
# 40                         Hood Baby    2.9M videos                      Kbfr
# 41                        Dream Girl   13.5M videos                   Ir Sais
# 42    Stunnin' (feat. Harm Franklin)    1.1M videos             Curtis Waters
# 43                             Do It  468.3K videos             Chloe x Halle
# 44  Savage Love (Laxed - Siren Beat)    785K videos  Jawsh 685 & Jason Derulo
# 45                      Mr. Blue Sky  546.8K videos  Electric Light Orchestra
# 46          Monkeys Spinning Monkeys    9.9M videos             Kevin MacLeod
# 47            Woah (feat. D3Mstreet)   12.4M videos                KRYPTO9095
#
#                                                  link  round playToken  \
# 39  /music/Then-Leave-feat-Queendom-Come-680828709...  False
# 40               /music/Hood-Baby-6812545347835922434  False
# 41              /music/Dream-Girl-6807966889273346822  False
# 42  /music/Stunnin-feat-Harm-Franklin-681313495626...  False
# 43                   /music/Do-It-6827517892439968517  False
# 44  /music/Savage-Love-Laxed-Siren-Beat-6834110584...  False
# 45             /music/Mr-Blue-Sky-6754420279457565445  False
# 46  /music/Monkeys-Spinning-Monkeys-67469933528911...  False
# 47     /music/Woah-feat-D3Mstreet-6691366574592396038  False
#
#    keyToken  ... relation challengeId              musicId       posts  likes  \
# 39           ...      NaN        None  6808287098886424577   1100000.0   None
# 40           ...      NaN        None  6812545347835922434   2900000.0   None
# 41           ...      NaN        None  6807966889273346822  13500000.0   None
# 42           ...      NaN        None  6813134956269947654   1100000.0   None
# 43           ...      NaN        None  6827517892439968517    468300.0   None
# 44           ...      NaN        None  6834110584288447237    785000.0   None
# 45           ...      NaN        None  6754420279457565445    546800.0   None
# 46           ...      NaN        None  6746993352891189249   9900000.0   None
# 47           ...      NaN        None  6691366574592396038  12400000.0   None
#
#    secUid userId  challengeName views  \
# 39   None   None           None  None
# 40   None   None           None  None
# 41   None   None           None  None
# 42   None   None           None  None
# 43   None   None           None  None
# 44   None   None           None  None
# 45   None   None           None  None
# 46   None   None           None  None
# 47   None   None           None  None
#
#                                               playUrl
# 39  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 40  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 41  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 42  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 43  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 44  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 45  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 46  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
# 47  [https://sf16-ies-music-sg.tiktokcdn.com/obj/t...
#
# [9 rows x 24 columns]

# %%
def parse_number(num: str) -> int:
    videos = num.split()[0]
    number = videos[:-1]
    units = videos[-1]
    units_mapper = {
        "K": 1,
        "M": 1000,
        "B": 1000000
    }
    return (float(number)) * float(units_mapper.get(units))

# %%
df = pd.DataFrame(music_df['subTitle'])
df
# Out:
#          subTitle
# 39    1.1M videos
# 40    2.9M videos
# 41   13.5M videos
# 42    1.1M videos
# 43  468.3K videos
# 44    785K videos
# 45  546.8K videos
# 46    9.9M videos
# 47   12.4M videos

# %%
df['videos_count (in thousands)'] = df['subTitle'].apply(parse_number)
df
# Out:
#          subTitle  videos_count (in thousands)
# 39    1.1M videos                       1100.0
# 40    2.9M videos                       2900.0
# 41   13.5M videos                      13500.0
# 42    1.1M videos                       1100.0
# 43  468.3K videos                        468.3
# 44    785K videos                        785.0
# 45  546.8K videos                        546.8
# 46    9.9M videos                       9900.0
# 47   12.4M videos                      12400.0

# %%
music_merged = pd.merge(music_df, df).drop(columns=
                                           ['subTitle',
                                            'cover', 
                                            'round', 
                                            'keyToken', 
                                            'playToken', 
                                            'extraInfo', 
                                            'type', 
                                            'extraInfo',
                                            'roomId',
                                            'fans',
                                            'verified',
                                            'relation',
                                            'challengeId',
                                            'musicId',
                                            'posts',
                                            'likes',
                                            'secUid',
                                            'userId',
                                            'challengeName',
                                            'views',
                                            'playUrl'])
music_merged
# Out:
#                      id                             title  \
# 0   6808287098886424577  Then Leave (feat. Queendom Come)
# 1   6808287098886424577  Then Leave (feat. Queendom Come)
# 2   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 3   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6812545347835922434                         Hood Baby
# 5   6807966889273346822                        Dream Girl
# 6   6827517892439968517                             Do It
# 7   6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8   6754420279457565445                      Mr. Blue Sky
# 9   6746993352891189249          Monkeys Spinning Monkeys
# 10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                  description  \
# 0                   BeatKing
# 1                   BeatKing
# 2              Curtis Waters
# 3              Curtis Waters
# 4                       Kbfr
# 5                    Ir Sais
# 6              Chloe x Halle
# 7   Jawsh 685 & Jason Derulo
# 8   Electric Light Orchestra
# 9              Kevin MacLeod
# 10                KRYPTO9095
#
#                                                  link  \
# 0   /music/Then-Leave-feat-Queendom-Come-680828709...
# 1   /music/Then-Leave-feat-Queendom-Come-680828709...
# 2   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 3   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 4                /music/Hood-Baby-6812545347835922434
# 5               /music/Dream-Girl-6807966889273346822
# 6                    /music/Do-It-6827517892439968517
# 7   /music/Savage-Love-Laxed-Siren-Beat-6834110584...
# 8              /music/Mr-Blue-Sky-6754420279457565445
# 9   /music/Monkeys-Spinning-Monkeys-67469933528911...
# 10     /music/Woah-feat-D3Mstreet-6691366574592396038
#
#     videos_count (in thousands)
# 0                        1100.0
# 1                        1100.0
# 2                        1100.0
# 3                        1100.0
# 4                        2900.0
# 5                       13500.0
# 6                         468.3
# 7                         785.0
# 8                         546.8
# 9                        9900.0
# 10                      12400.0

# %%
music_clean = music_merged.rename(columns={
    'id': 'Song ID',
    'title': 'Song Name',
    'description': 'Artist',
    'link': 'Link to Trend Page',
    'videos_count (in thousands)': 'Number of Videos with Song (in Thousands)'
})
music_clean
# Out:
#                 Song ID                         Song Name  \
# 0   6808287098886424577  Then Leave (feat. Queendom Come)
# 1   6808287098886424577  Then Leave (feat. Queendom Come)
# 2   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 3   6813134956269947654    Stunnin' (feat. Harm Franklin)
# 4   6812545347835922434                         Hood Baby
# 5   6807966889273346822                        Dream Girl
# 6   6827517892439968517                             Do It
# 7   6834110584288447237  Savage Love (Laxed - Siren Beat)
# 8   6754420279457565445                      Mr. Blue Sky
# 9   6746993352891189249          Monkeys Spinning Monkeys
# 10  6691366574592396038            Woah (feat. D3Mstreet)
#
#                       Artist  \
# 0                   BeatKing
# 1                   BeatKing
# 2              Curtis Waters
# 3              Curtis Waters
# 4                       Kbfr
# 5                    Ir Sais
# 6              Chloe x Halle
# 7   Jawsh 685 & Jason Derulo
# 8   Electric Light Orchestra
# 9              Kevin MacLeod
# 10                KRYPTO9095
#
#                                    Link to Trend Page  \
# 0   /music/Then-Leave-feat-Queendom-Come-680828709...
# 1   /music/Then-Leave-feat-Queendom-Come-680828709...
# 2   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 3   /music/Stunnin-feat-Harm-Franklin-681313495626...
# 4                /music/Hood-Baby-6812545347835922434
# 5               /music/Dream-Girl-6807966889273346822
# 6                    /music/Do-It-6827517892439968517
# 7   /music/Savage-Love-Laxed-Siren-Beat-6834110584...
# 8              /music/Mr-Blue-Sky-6754420279457565445
# 9   /music/Monkeys-Spinning-Monkeys-67469933528911...
# 10     /music/Woah-feat-D3Mstreet-6691366574592396038
#
#     Number of Videos with Song (in Thousands)
# 0                                      1100.0
# 1                                      1100.0
# 2                                      1100.0
# 3                                      1100.0
# 4                                      2900.0
# 5                                     13500.0
# 6                                       468.3
# 7                                       785.0
# 8                                       546.8
# 9                                      9900.0
# 10                                    12400.0

# %%
music_clean.to_csv('music_data.csv')

# %%
users_df = parsed_df[parsed_df['type'] == 2]
users_df
# Out:
#                      id  type  \
# 0   6748458643983238149     2
# 1               5831967     2
# 2   6739078402710553605     2
# 3   6727327145951183878     2
# 4   6703550784929793030     2
# 5   6587535917023182853     2
# 6   6669716864531054598     2
# 7   6699542567460389894     2
# 8   6663294979903422470     2
# 9     84635664075374592     2
# 10  6654362767867265030     2
# 11              7239462     2
# 12  6904838098921440262     2
# 13  6718992235998741510     2
# 14  6813630187164533765     2
# 15  6625714545389142022     2
# 16  6544081646253342726     2
# 17  6757817457937499141     2
# 18  6732675975610074118     2
# 19  6767527973299536901     2
# 20  6781939622308037638     2
# 21              1180651     2
# 22  6763517179218330630     2
# 23  6695492574909613061     2
# 24  6780564068844880902     2
# 25  6658722935124328453     2
# 26  6746417382892176389     2
# 27  6646764999833403398     2
# 28  6957597538883142661     2
#
#                                                 cover              title  \
# 0   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Bella Poarch
# 1   https://p16-sign-va.tiktokcdn.com/musically-ma...    charli d’amelio
# 2   https://p16-sign-va.tiktokcdn.com/musically-ma...  Dr. Daniel Aronov
# 3   https://p16-sign-va.tiktokcdn.com/musically-ma...         Will Smith
# 4   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        addison rae
# 5   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...     Daniel LaBelle
# 6   https://p16-sign-va.tiktokcdn.com/tos-maliva-a...    Brody Wellmaker
# 7   https://p16-sign-va.tiktokcdn.com/musically-ma...         Jay Brewer
# 8   https://p16-sign-va.tiktokcdn.com/musically-ma...               ESPN
# 9   https://p16-sign-va.tiktokcdn.com/musically-ma...              lizzo
# 10  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...      Kylie Jenner
# 11  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       Malu Trevejo
# 12  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...     northeasterner
# 13  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...            Scott 🔥
# 14  https://p16-sign-va.tiktokcdn.com/musically-ma...          siennamae
# 15  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...           Overtime
# 16  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...                 Ri
# 17  https://p16-sign-va.tiktokcdn.com/musically-ma...       Tooturnttony
# 18  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        Brooke Monk
# 19  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       AbbieHerbert
# 20  https://p16-sign-va.tiktokcdn.com/musically-ma...         Jack Black
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...        bretmanrock
# 22  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...      otakoyakisoba
# 23  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...            choctiv
# 24  https://p16-sign-va.tiktokcdn.com/musically-ma...        Mia Khalifa
# 25  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...          lil nas x
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...          KEEMOKAZI
# 27  https://p16-sign-va.tiktokcdn.com/musically-ma...    Barstool Sports
# 28  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...     LIGHTS ARE OFF
#
#                subTitle                                        description  \
# 0          @bellapoarch                 BUILD A BITCH MUSIC VIDEO OUT NOW😈
# 1        @charlidamelio
# 2      @dr.danielaronov  See ALL my surgeries on my Instagram! INQUIRIE...
# 3            @willsmith                         Same kid from West Philly.
# 4            @addisonre                     OBSESSED out on all platforms.
# 5       @daniel.labelle
# 6       @brodywellmaker  Trying to sneak my way into Hollywood 🤫 \nbrod...
# 7   @jayprehistoricpets  Sub to my YouTube for even more animal fun see...
# 8                 @espn                      You won’t regret following! 🔥
# 9                @lizzo                                    100% that bitch
# 10         @kyliejenner               The official account of Kylie Jenner
# 11         @malutrevejo                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋
# 12      @northeasterner                 Follow me to watch more food video
# 13       @scottsreality  Donating to new IG followers!💰 \n📧 Scott@grail...
# 14           @siennamae                  I’ll be famous one day\nceo of 🐿💨
# 15            @overtime  Best page in the galaxy 💫\nThanks for being my...
# 16               @riwww  I’m Renata. 18\nthx 6m \ninsta: @ri.www\nRi.co...
# 17        @tooturnttony           DM me on Connected2me! \nDownload here 👇
# 18         @brookemonk_  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...
# 19       @abbieherbert_  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...
# 20           @jackblack
# 21         @bretmanrock                                             legend
# 22       @otakoyakisoba  Olly & Mama LuLu\nYour favorite Mother & Son d...
# 23             @choctiv  INSTA: @choctiv 😈\nLIL EINSTEIN OUT NOW ! 🚀💫\n...
# 24          @miakhalifa       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co
# 25             @lilnasx  “MONTERO (CALL ME BY YOUR NAME)” & “SUN GOES D...
# 26           @keemokazi  Following back on IG for the next 24 hours ↖️🔥...
# 27      @barstoolsports          🗣 Viva La Stool\n\nGoing viral is a sport
# 28      @lights.are.off  LIGHTS ARE OFF\nI bring nightmares to life eve...
#
#                     link  round playToken keyToken  ... relation challengeId  \
# 0          /@bellapoarch   True                     ...     -1.0        None
# 1        /@charlidamelio   True                     ...     -1.0        None
# 2      /@dr.danielaronov   True                     ...     -1.0        None
# 3            /@willsmith   True                     ...     -1.0        None
# 4            /@addisonre   True                     ...     -1.0        None
# 5       /@daniel.labelle   True                     ...     -1.0        None
# 6       /@brodywellmaker   True                     ...     -1.0        None
# 7   /@jayprehistoricpets   True                     ...     -1.0        None
# 8                 /@espn   True                     ...     -1.0        None
# 9                /@lizzo   True                     ...     -1.0        None
# 10         /@kyliejenner   True                     ...     -1.0        None
# 11         /@malutrevejo   True                     ...     -1.0        None
# 12      /@northeasterner   True                     ...     -1.0        None
# 13       /@scottsreality   True                     ...     -1.0        None
# 14           /@siennamae   True                     ...     -1.0        None
# 15            /@overtime   True                     ...     -1.0        None
# 16               /@riwww   True                     ...     -1.0        None
# 17        /@tooturnttony   True                     ...     -1.0        None
# 18         /@brookemonk_   True                     ...     -1.0        None
# 19       /@abbieherbert_   True                     ...     -1.0        None
# 20           /@jackblack   True                     ...     -1.0        None
# 21         /@bretmanrock   True                     ...     -1.0        None
# 22       /@otakoyakisoba   True                     ...     -1.0        None
# 23             /@choctiv   True                     ...     -1.0        None
# 24          /@miakhalifa   True                     ...     -1.0        None
# 25             /@lilnasx   True                     ...     -1.0        None
# 26           /@keemokazi   True                     ...     -1.0        None
# 27      /@barstoolsports   True                     ...     -1.0        None
# 28      /@lights.are.off   True                     ...     -1.0        None
#
#     musicId posts       likes  \
# 0      None   NaN  1600000000
# 1      None   NaN  9400000000
# 2      None   NaN   214900000
# 3      None   NaN   332500000
# 4      None   NaN  5200000000
# 5      None   NaN   421600000
# 6      None   NaN   328100000
# 7      None   NaN   170600000
# 8      None   NaN  1100000000
# 9      None   NaN   493400000
# 10     None   NaN   369400000
# 11     None   NaN   439200000
# 12     None   NaN    77400000
# 13     None   NaN   443100000
# 14     None   NaN   892500000
# 15     None   NaN  1200000000
# 16     None   NaN   182800000
# 17     None   NaN   329600000
# 18     None   NaN  1100000000
# 19     None   NaN   641200000
# 20     None   NaN    62300000
# 21     None   NaN   216300000
# 22     None   NaN   392800000
# 23     None   NaN    80400000
# 24     None   NaN   288400000
# 25     None   NaN   543900000
# 26     None   NaN   753800000
# 27     None   NaN   847000000
# 28     None   NaN    50400000
#
#                                                secUid               userId  \
# 0   MS4wLjABAAAAIQGNoHByQvokcLbWCGnIfas0OV2nctsZnR...  6748458643983238149
# 1   MS4wLjABAAAA-VASjiXTh7wDDyXvjk10VFhMWUAoxr8bgf...              5831967
# 2   MS4wLjABAAAADfrPcyWFROfYl4vfjYJ9_g4hCUwaNqG-FC...  6739078402710553605
# 3   MS4wLjABAAAA8ezUaW4ecJX222ObGXxt07F9BIh4QH3-g1...  6727327145951183878
# 4   MS4wLjABAAAAVjQK614JSGmZVT3EVAiSDfznaBJOVfWPrt...  6703550784929793030
# 5   MS4wLjABAAAA2sCfGnqRN1c0jn5CxmbkNDWyI39XImwnfb...  6587535917023182853
# 6   MS4wLjABAAAAAzAz4PbZuttUx6tq4zteYqIXUwmEo28tPf...  6669716864531054598
# 7   MS4wLjABAAAAKtlitna177EaY3JAgDPnjAfZj8kI-GnaM5...  6699542567460389894
# 8   MS4wLjABAAAAbq-1Yqpp1a6u5KbV_sMg93_FK7AN3d6MJe...  6663294979903422470
# 9   MS4wLjABAAAAbDLA4RLGE_qKD2V_5xJU7QiC19CS6JLNQE...    84635664075374592
# 10  MS4wLjABAAAArK0Wz24jqHzcTuvH6y7H0KZJEbfgbCp03n...  6654362767867265030
# 11  MS4wLjABAAAAY5rcnL7T81JsGRfsyHBYZfpCHG1pP3sL9w...              7239462
# 12  MS4wLjABAAAApUjASvwSGjM3IgEObm2vzwCu8vkb9_UTIX...  6904838098921440262
# 13  MS4wLjABAAAAQq58m31S-GAQ7zOvlqwAVJ39xsO_LwHgXY...  6718992235998741510
# 14  MS4wLjABAAAAOc-TrMCOI1gJwgKEJGzjfD2yX7DNxjjjRx...  6813630187164533765
# 15  MS4wLjABAAAAFcC3aBBWR4UJgsXyo5ztXlMTw4Kb8eeTTo...  6625714545389142022
# 16  MS4wLjABAAAA9pbVRTj-HguyV_kJdmz6lQCY8ec5YH6PJF...  6544081646253342726
# 17  MS4wLjABAAAAbghIQMtxl7dcXpPYrp37EgUf04S9TxwplI...  6757817457937499141
# 18  MS4wLjABAAAAA2kM2Gtlz16uiw_OgD_xmL6sqfg42RMHLY...  6732675975610074118
# 19  MS4wLjABAAAAmyJNDiXiVG7rb2M4WVMvjDwJU_Tfw22k8o...  6767527973299536901
# 20  MS4wLjABAAAA1K_ef7JsnWLe1uLwjsomAp-yhlHeFze3wV...  6781939622308037638
# 21  MS4wLjABAAAAJIgaTReWDyMmZgpFNtrSU267Ep8HX4KxWZ...              1180651
# 22  MS4wLjABAAAA3ZG_uAFM-vf9Omw6sxWqU8Bh-ZY-Ewnqbr...  6763517179218330630
# 23  MS4wLjABAAAAlOKx0CGCiO-JYyOJ5o4FjKiLy3WLZtg3yi...  6695492574909613061
# 24  MS4wLjABAAAAqRy-nnmorDVMJ1JddqSqduRvlpsNEiZN8A...  6780564068844880902
# 25  MS4wLjABAAAAS9ciBdtH3kzTIz09dQVBybwPFnbjO-Q5Fq...  6658722935124328453
# 26  MS4wLjABAAAAwOIa5vSA9Qy40SlT9q4Y9LhCTR__vPTjLQ...  6746417382892176389
# 27  MS4wLjABAAAAV-FnuTQImr7z9AvHTeDfA1zge-srWKQv8v...  6646764999833403398
# 28  MS4wLjABAAAAOfW3UzLFyh5oMJNYvSZBTqy_9_TJhUscRN...  6957597538883142661
#
#     challengeName views playUrl
# 0            None  None    None
# 1            None  None    None
# 2            None  None    None
# 3            None  None    None
# 4            None  None    None
# 5            None  None    None
# 6            None  None    None
# 7            None  None    None
# 8            None  None    None
# 9            None  None    None
# 10           None  None    None
# 11           None  None    None
# 12           None  None    None
# 13           None  None    None
# 14           None  None    None
# 15           None  None    None
# 16           None  None    None
# 17           None  None    None
# 18           None  None    None
# 19           None  None    None
# 20           None  None    None
# 21           None  None    None
# 22           None  None    None
# 23           None  None    None
# 24           None  None    None
# 25           None  None    None
# 26           None  None    None
# 27           None  None    None
# 28           None  None    None
#
# [29 rows x 24 columns]

# %%
users = users_df.drop(columns=
              ['playToken', 
               'keyToken', 
               'type',
               'link', 
               'round',
               'extraInfo',
               'roomId',
                'relation',
                'challengeId',
                'musicId',
                'posts',
                'secUid',
                'userId',
                'challengeName',
                'views',
                'playUrl'])
users
# Out:
#                      id                                              cover  \
# 0   6748458643983238149  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 1               5831967  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 2   6739078402710553605  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 3   6727327145951183878  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   6703550784929793030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 5   6587535917023182853  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   6669716864531054598  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 7   6699542567460389894  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   6663294979903422470  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 9     84635664075374592  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 10  6654362767867265030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11              7239462  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 12  6904838098921440262  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  6718992235998741510  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 14  6813630187164533765  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 15  6625714545389142022  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  6544081646253342726  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 17  6757817457937499141  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 18  6732675975610074118  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  6767527973299536901  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  6781939622308037638  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 21              1180651  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22  6763517179218330630  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 23  6695492574909613061  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 24  6780564068844880902  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  6658722935124328453  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 26  6746417382892176389  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27  6646764999833403398  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  6957597538883142661  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
#
#                 title             subTitle  \
# 0        Bella Poarch         @bellapoarch
# 1     charli d’amelio       @charlidamelio
# 2   Dr. Daniel Aronov     @dr.danielaronov
# 3          Will Smith           @willsmith
# 4         addison rae           @addisonre
# 5      Daniel LaBelle      @daniel.labelle
# 6     Brody Wellmaker      @brodywellmaker
# 7          Jay Brewer  @jayprehistoricpets
# 8                ESPN                @espn
# 9               lizzo               @lizzo
# 10      Kylie Jenner          @kyliejenner
# 11       Malu Trevejo         @malutrevejo
# 12     northeasterner      @northeasterner
# 13            Scott 🔥       @scottsreality
# 14          siennamae           @siennamae
# 15           Overtime            @overtime
# 16                 Ri               @riwww
# 17       Tooturnttony        @tooturnttony
# 18        Brooke Monk         @brookemonk_
# 19       AbbieHerbert       @abbieherbert_
# 20         Jack Black           @jackblack
# 21        bretmanrock         @bretmanrock
# 22      otakoyakisoba       @otakoyakisoba
# 23            choctiv             @choctiv
# 24        Mia Khalifa          @miakhalifa
# 25          lil nas x             @lilnasx
# 26          KEEMOKAZI           @keemokazi
# 27    Barstool Sports      @barstoolsports
# 28     LIGHTS ARE OFF      @lights.are.off
#
#                                           description         fans verified  \
# 0                  BUILD A BITCH MUSIC VIDEO OUT NOW😈   71400000.0     True
# 1                                                      116900000.0     True
# 2   See ALL my surgeries on my Instagram! INQUIRIE...   12300000.0     True
# 3                          Same kid from West Philly.   54900000.0     True
# 4                      OBSESSED out on all platforms.   80800000.0     True
# 5                                                       19700000.0     True
# 6   Trying to sneak my way into Hollywood 🤫 \nbrod...   11800000.0     True
# 7   Sub to my YouTube for even more animal fun see...   13400000.0     True
# 8                       You won’t regret following! 🔥   16400000.0     True
# 9                                     100% that bitch   16000000.0     True
# 10               The official account of Kylie Jenner   32100000.0     True
# 11                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋   17400000.0     True
# 12                 Follow me to watch more food video    5300000.0    False
# 13  Donating to new IG followers!💰 \n📧 Scott@grail...   24200000.0     True
# 14                  I’ll be famous one day\nceo of 🐿💨   14600000.0     True
# 15  Best page in the galaxy 💫\nThanks for being my...   16800000.0     True
# 16  I’m Renata. 18\nthx 6m \ninsta: @ri.www\nRi.co...    6900000.0    False
# 17           DM me on Connected2me! \nDownload here 👇    8700000.0     True
# 18  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...   15400000.0     True
# 19  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...    8700000.0     True
# 20                                                      10200000.0     True
# 21                                             legend   11400000.0     True
# 22  Olly & Mama LuLu\nYour favorite Mother & Son d...    9200000.0     True
# 23  INSTA: @choctiv 😈\nLIL EINSTEIN OUT NOW ! 🚀💫\n...    4500000.0     True
# 24       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co   23100000.0     True
# 25  “MONTERO (CALL ME BY YOUR NAME)” & “SUN GOES D...   16600000.0     True
# 26  Following back on IG for the next 24 hours ↖️🔥...   18300000.0     True
# 27          🗣 Viva La Stool\n\nGoing viral is a sport   13600000.0     True
# 28  LIGHTS ARE OFF\nI bring nightmares to life eve...    4900000.0    False
#
#          likes
# 0   1600000000
# 1   9400000000
# 2    214900000
# 3    332500000
# 4   5200000000
# 5    421600000
# 6    328100000
# 7    170600000
# 8   1100000000
# 9    493400000
# 10   369400000
# 11   439200000
# 12    77400000
# 13   443100000
# 14   892500000
# 15  1200000000
# 16   182800000
# 17   329600000
# 18  1100000000
# 19   641200000
# 20    62300000
# 21   216300000
# 22   392800000
# 23    80400000
# 24   288400000
# 25   543900000
# 26   753800000
# 27   847000000
# 28    50400000

# %%
users_clean = users.rename(columns={
    'id': 'User ID',
    'cover': "User's Cover Picture",
    'title': "User's Name",
    'subTitle': "User's Handle",
    'description': 'Description',
    'fans': 'Followers',
    'verified': 'Verified',
    'likes': 'Likes'
})
users_clean
# Out:
#                 User ID                               User's Cover Picture  \
# 0   6748458643983238149  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 1               5831967  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 2   6739078402710553605  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 3   6727327145951183878  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 4   6703550784929793030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 5   6587535917023182853  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 6   6669716864531054598  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 7   6699542567460389894  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 8   6663294979903422470  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 9     84635664075374592  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 10  6654362767867265030  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 11              7239462  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 12  6904838098921440262  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 13  6718992235998741510  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 14  6813630187164533765  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 15  6625714545389142022  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 16  6544081646253342726  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 17  6757817457937499141  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 18  6732675975610074118  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 19  6767527973299536901  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 20  6781939622308037638  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 21              1180651  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 22  6763517179218330630  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 23  6695492574909613061  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 24  6780564068844880902  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 25  6658722935124328453  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 26  6746417382892176389  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
# 27  6646764999833403398  https://p16-sign-va.tiktokcdn.com/musically-ma...
# 28  6957597538883142661  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...
#
#           User's Name        User's Handle  \
# 0        Bella Poarch         @bellapoarch
# 1     charli d’amelio       @charlidamelio
# 2   Dr. Daniel Aronov     @dr.danielaronov
# 3          Will Smith           @willsmith
# 4         addison rae           @addisonre
# 5      Daniel LaBelle      @daniel.labelle
# 6     Brody Wellmaker      @brodywellmaker
# 7          Jay Brewer  @jayprehistoricpets
# 8                ESPN                @espn
# 9               lizzo               @lizzo
# 10      Kylie Jenner          @kyliejenner
# 11       Malu Trevejo         @malutrevejo
# 12     northeasterner      @northeasterner
# 13            Scott 🔥       @scottsreality
# 14          siennamae           @siennamae
# 15           Overtime            @overtime
# 16                 Ri               @riwww
# 17       Tooturnttony        @tooturnttony
# 18        Brooke Monk         @brookemonk_
# 19       AbbieHerbert       @abbieherbert_
# 20         Jack Black           @jackblack
# 21        bretmanrock         @bretmanrock
# 22      otakoyakisoba       @otakoyakisoba
# 23            choctiv             @choctiv
# 24        Mia Khalifa          @miakhalifa
# 25          lil nas x             @lilnasx
# 26          KEEMOKAZI           @keemokazi
# 27    Barstool Sports      @barstoolsports
# 28     LIGHTS ARE OFF      @lights.are.off
#
#                                           Description    Followers Verified  \
# 0                  BUILD A BITCH MUSIC VIDEO OUT NOW😈   71400000.0     True
# 1                                                      116900000.0     True
# 2   See ALL my surgeries on my Instagram! INQUIRIE...   12300000.0     True
# 3                          Same kid from West Philly.   54900000.0     True
# 4                      OBSESSED out on all platforms.   80800000.0     True
# 5                                                       19700000.0     True
# 6   Trying to sneak my way into Hollywood 🤫 \nbrod...   11800000.0     True
# 7   Sub to my YouTube for even more animal fun see...   13400000.0     True
# 8                       You won’t regret following! 🔥   16400000.0     True
# 9                                     100% that bitch   16000000.0     True
# 10               The official account of Kylie Jenner   32100000.0     True
# 11                        18💜♎️ 🇨🇺 🇪🇸 \nI’m back :) 🦋   17400000.0     True
# 12                 Follow me to watch more food video    5300000.0    False
# 13  Donating to new IG followers!💰 \n📧 Scott@grail...   24200000.0     True
# 14                  I’ll be famous one day\nceo of 🐿💨   14600000.0     True
# 15  Best page in the galaxy 💫\nThanks for being my...   16800000.0     True
# 16  I’m Renata. 18\nthx 6m \ninsta: @ri.www\nRi.co...    6900000.0    False
# 17           DM me on Connected2me! \nDownload here 👇    8700000.0     True
# 18  ❤️Jesus forever❤️\n 18\nI’m not funny \nNew Yo...   15400000.0     True
# 19  Mom, Wife, & Model\nThe Herbert’s YouTube ⬇️\n...    8700000.0     True
# 20                                                      10200000.0     True
# 21                                             legend   11400000.0     True
# 22  Olly & Mama LuLu\nYour favorite Mother & Son d...    9200000.0     True
# 23  INSTA: @choctiv 😈\nLIL EINSTEIN OUT NOW ! 🚀💫\n...    4500000.0     True
# 24       Immigrant 🇱🇧 Not Malala. Inquiries@Myotis.co   23100000.0     True
# 25  “MONTERO (CALL ME BY YOUR NAME)” & “SUN GOES D...   16600000.0     True
# 26  Following back on IG for the next 24 hours ↖️🔥...   18300000.0     True
# 27          🗣 Viva La Stool\n\nGoing viral is a sport   13600000.0     True
# 28  LIGHTS ARE OFF\nI bring nightmares to life eve...    4900000.0    False
#
#          Likes
# 0   1600000000
# 1   9400000000
# 2    214900000
# 3    332500000
# 4   5200000000
# 5    421600000
# 6    328100000
# 7    170600000
# 8   1100000000
# 9    493400000
# 10   369400000
# 11   439200000
# 12    77400000
# 13   443100000
# 14   892500000
# 15  1200000000
# 16   182800000
# 17   329600000
# 18  1100000000
# 19   641200000
# 20    62300000
# 21   216300000
# 22   392800000
# 23    80400000
# 24   288400000
# 25   543900000
# 26   753800000
# 27   847000000
# 28    50400000

# %%
users_clean.to_csv('users_data.csv')

# %%
hashtags_df = parsed_df[parsed_df['type'] == 3]
hashtags_df
# Out:
#                   id  type                                              cover  \
# 29            400318     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 30  1647119754150918     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 31  1662027712917510     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 32  1637138684632070     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 33  1587934459506690     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 34             27892     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 35  1596232738661382     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 36           4174123     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 37          12106204     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
# 38          15290423     3  https://p16-amd-va.tiktokcdn.com/obj/musically...
#
#                  title      subTitle  \
# 29          #buffering  443.8M views
# 30  #tiktokmademebuyit    2.8B views
# 31       #prideanthems   38.1M views
# 32       #foryourpride  466.2M views
# 33          #tiktokart    5.8B views
# 34        #memorialday  830.9M views
# 35     #dreamaesthetic  143.4M views
# 36        #classof2021    1.3B views
# 37        #todayislove  288.1M views
# 38           #uclfinal  530.9M views
#
#                                           description                    link  \
# 29  Use our Creative Effect and show us what happe...          /tag/buffering
# 30  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 31  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 32  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 33  From painters to sculptures and everything in ...          /tag/tiktokart
# 34                        Commemorating #MemorialDay.        /tag/memorialday
# 35                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 36  Whether you're celebrating online or just part...        /tag/classof2021
# 37                       #TodayIsLove! We love today.        /tag/todayislove
# 38  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#     round playToken keyToken  ... relation       challengeId  musicId posts  \
# 29  False                     ...      NaN            400318     None   NaN
# 30  False                     ...      NaN  1647119754150918     None   NaN
# 31  False                     ...      NaN  1662027712917510     None   NaN
# 32  False                     ...      NaN  1637138684632070     None   NaN
# 33  False                     ...      NaN  1587934459506690     None   NaN
# 34  False                     ...      NaN             27892     None   NaN
# 35  False                     ...      NaN  1596232738661382     None   NaN
# 36  False                     ...      NaN           4174123     None   NaN
# 37  False                     ...      NaN          12106204     None   NaN
# 38  False                     ...      NaN          15290423     None   NaN
#
#     likes secUid userId      challengeName       views playUrl
# 29   None   None   None          buffering   443800000    None
# 30   None   None   None  tiktokmademebuyit  2800000000    None
# 31   None   None   None       prideanthems    38100000    None
# 32   None   None   None       foryourpride   466200000    None
# 33   None   None   None          tiktokart  5800000000    None
# 34   None   None   None        memorialday   830900000    None
# 35   None   None   None     dreamaesthetic   143400000    None
# 36   None   None   None        classof2021  1300000000    None
# 37   None   None   None        todayislove   288100000    None
# 38   None   None   None           uclfinal   530900000    None
#
# [10 rows x 24 columns]

# %%
def parse_number(num: str) -> int:
    videos = num.split()[0]
    number = videos[:-1]
    units = videos[-1]
    units_mapper = {
        "K": 1,
        "M": 1000,
        "B": 1000000
    }
    return (float(number)) * float(units_mapper.get(units))

# %%
df = pd.DataFrame(hashtags_df['subTitle'])
df
# Out:
#         subTitle
# 29  443.8M views
# 30    2.8B views
# 31   38.1M views
# 32  466.2M views
# 33    5.8B views
# 34  830.9M views
# 35  143.4M views
# 36    1.3B views
# 37  288.1M views
# 38  530.9M views

# %%
df['videos_count'] = df['subTitle'].apply(parse_number)
df
# Out:
#         subTitle  videos_count
# 29  443.8M views      443800.0
# 30    2.8B views     2800000.0
# 31   38.1M views       38100.0
# 32  466.2M views      466200.0
# 33    5.8B views     5800000.0
# 34  830.9M views      830900.0
# 35  143.4M views      143400.0
# 36    1.3B views     1300000.0
# 37  288.1M views      288100.0
# 38  530.9M views      530900.0

# %%
hashtag_merged = pd.merge(hashtags_df, df).drop(columns=
                                                ['subTitle', 
                                                 'cover', 
                                                 'round', 
                                                 'keyToken', 
                                                 'playToken', 
                                                 'extraInfo', 
                                                 'type',
                                                 'extraInfo',
                                                 'roomId',
                                                 'relation',
                                                 'challengeId',
                                                 'musicId',
                                                 'posts',
                                                 'secUid',
                                                 'userId',
                                                 'challengeName',
                                                 'views',
                                                 'playUrl',
                                                 'fans',
                                                 'verified',
                                                 'likes'
                                                ])
hashtag_merged
# Out:
#                  id               title  \
# 0            400318          #buffering
# 1  1647119754150918  #tiktokmademebuyit
# 2  1662027712917510       #prideanthems
# 3  1637138684632070       #foryourpride
# 4  1587934459506690          #tiktokart
# 5             27892        #memorialday
# 6  1596232738661382     #dreamaesthetic
# 7           4174123        #classof2021
# 8          12106204        #todayislove
# 9          15290423           #uclfinal
#
#                                          description                    link  \
# 0  Use our Creative Effect and show us what happe...          /tag/buffering
# 1  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 2  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 3  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 4  From painters to sculptures and everything in ...          /tag/tiktokart
# 5                        Commemorating #MemorialDay.        /tag/memorialday
# 6                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 7  Whether you're celebrating online or just part...        /tag/classof2021
# 8                       #TodayIsLove! We love today.        /tag/todayislove
# 9  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#    videos_count
# 0      443800.0
# 1     2800000.0
# 2       38100.0
# 3      466200.0
# 4     5800000.0
# 5      830900.0
# 6      143400.0
# 7     1300000.0
# 8      288100.0
# 9      530900.0

# %%
hashtag_clean = hashtag_merged.rename(columns={
    'id': 'Hashtag ID',
    'title': 'Hashtag',
    'description': 'Description',
    'link': 'Link to Trend Page',
    'videos_count': 'Number of Videos with Hashtag (in Thousands)',
})
hashtag_clean
# Out:
#          Hashtag ID             Hashtag  \
# 0            400318          #buffering
# 1  1647119754150918  #tiktokmademebuyit
# 2  1662027712917510       #prideanthems
# 3  1637138684632070       #foryourpride
# 4  1587934459506690          #tiktokart
# 5             27892        #memorialday
# 6  1596232738661382     #dreamaesthetic
# 7           4174123        #classof2021
# 8          12106204        #todayislove
# 9          15290423           #uclfinal
#
#                                          Description      Link to Trend Page  \
# 0  Use our Creative Effect and show us what happe...          /tag/buffering
# 1  Whether you're still hunting for feta cheese o...  /tag/tiktokmademebuyit
# 2  Whether it's an iconic bop that's been an esse...       /tag/prideanthems
# 3  Pride Month is here, and TikTok is celebrating...       /tag/foryourpride
# 4  From painters to sculptures and everything in ...          /tag/tiktokart
# 5                        Commemorating #MemorialDay.        /tag/memorialday
# 6                       What's your #DreamAesthetic?     /tag/dreamaesthetic
# 7  Whether you're celebrating online or just part...        /tag/classof2021
# 8                       #TodayIsLove! We love today.        /tag/todayislove
# 9  The 2020/21 Champions League final is here! Us...           /tag/uclfinal
#
#    Number of Videos with Hashtag (in Thousands)
# 0                                      443800.0
# 1                                     2800000.0
# 2                                       38100.0
# 3                                      466200.0
# 4                                     5800000.0
# 5                                      830900.0
# 6                                      143400.0
# 7                                     1300000.0
# 8                                      288100.0
# 9                                      530900.0

# %%
hashtag_clean.to_csv('hashtag_data.csv')
